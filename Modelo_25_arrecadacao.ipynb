# %% [markdown]
# <strong><b><font size="5">Análise Estatística e Modelagem Preditiva de Séries Temporais - Em Python</font></b></strong>

# %% [markdown]
# <strong><b><font size="4">Otimização de Hiperparâmetros em Modelos de Deep Learning Para a Capacidade</font></b></strong>

# %% [markdown]
# Criamos alguns modelos de Deep Learning até aqui para prever nossa série temporal, mas não tivemos resultados realmente diferenciados. A vida como ela é na prática. Não espere mágica, isso não existe. O que existe é conhecimento e trabalho duro, assim que conquistamos resultados.
#
# Os modelos de Deep Learning não tem alcançado boa performance por uma razão simples: nosso conjunto de dados é pequeno. Deep Learning mostra seu brilho quando temos um volume de dados realmente grande (aquele tal de Big Data).
#
# Poderíamos, claro, trabalhar com a nossa série de vendas diárias e assim teríamos um volume de dados muito maior. Mas ao decidir trabalhar com a série da média mensal, precisaríamos de um volume de dados pelo menos 10x maior. Isso fica evidente pelos resultados similares em quase todos os modelos que criamos até aqui (com ou sem Deep Learning). Trabalhar com séries mensais é sempre um grande desafio e pode não ser a melhor opção.
#
# E por que trabalhamos com a média mensal e não as vendas diárias? Porque nosso objetivo neste curso era mostrar não apenas ferramentas e análise, mas as dificuldades inerentes ao processo, quando uma série é difícil de ajustar ou o volume de dados é pequeno. Dependendo do problema podemos não alcançar um resultado satisfatório. É assim que as coisas funcionam na vida real.
#
# **Mas vamos para mais uma tentativa. O trabalho em Data Science passa por experimentação e podemos experimentar outras abordagens e comparar os resultados.**
#
# Como diria Rocky Balboa: "Mais um round, por favor!"
#
# Nesta aula vamos aplicar uma mudança na preparação dos dados e criar um modelo LSTM Bidirectional (uma das arquiteturas de Deep Learning mais avançadas quando trabalhamos com séries usando modelos LSTM) e depois aplicar Grid Search para otimizar os hiperparâmetros do modelo e criar a versão final.
#
# Já posso antecipar: será a melhor versão dos modelos de Deep Learning que criamos até aqui.
#
# Resumindo o que faremos nesta aula:
#
# - Removeremos os picos de vendas da série original.
# - Criaremos a primeira versão do modelo LSTM Bidirectional.
# - Executaremos o Grid Search para buscar os melhores hiperparâmetros.
# - Criaremos a versão final do modelo com os melhores hiperparâmetros.
#
# Esta aula considera que você já tem alguma noção sobre o que é Deep Learning e a definição de Deep Learning.
#
# Esse conhecimento pode ser obtido no material gratuito fornecido pela DSA, o <a href="http://www.deeplearningbook.com.br/">Deep Learning Book</a>. Lá você encontra alguns capítulos inteiros dedicados às LSTMs. Recomendamos a leitura antes de prosseguir nesta aula.
#
# A execução do Jupyter Notebook desta aula vai levar um bom tempo, pois está "pesadão". Seja paciente!
#
# Se estiver com um tempo de sobra, depois experimente o pacote xarray, que otimiza o trabalho com séries temporais em Python (de fato otimiza o trabalho com diversas estruturas de dados): http://xarray.pydata.org/en/v0.15.1/time-series.html

# %%
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# Imports para manipulação de dados
import math
import numpy as np
import pandas as pd
import itertools
from pandas import Series
from pandas.tseries.offsets import DateOffset

# Imports para visualização de dados
import matplotlib.pyplot as plt
import matplotlib as m
import seaborn as sns

# Imports para modelagem preditiva
import sklearn
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import statsmodels
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.stats as sms
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# Imports para formatação dos gráficos
plt.style.use('fivethirtyeight')
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10
#matplotlib.style.use('ggplot')
#%matplotlib inline

from time import time

# %%
# Imports para modelagem preditiva - Tensorflow 1.
#import keras
#from keras.preprocessing.sequence import TimeseriesGenerator
#from keras.models import Sequential
#from keras.layers.core import Dense, Activation
#from keras.layers import LSTM
#from keras.layers import Dropout

# %%
# Imports para modelagem preditiva - Tensorflow 2.0
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
print(tf.__version__)
# Out:
# 2.0.0

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# pandas                1.0.5
# seaborn               0.10.1
# sklearn               0.23.1
# statsmodels           0.11.1
# tensorflow            2.0.0
# statsmodels.api       0.11.1
# matplotlib            3.3.0
# numpy                 1.16.6
# tensorflow_core.keras 2.2.4-tf
# Data Science Academy

# %% [markdown]
# ## Definição do Problema de Negócio
#
# Previsão de arrecadação de ICMS.

# %% [markdown]
# ## Conjunto de Dados

# %% [markdown]
# Usaremos conjuntos de dados que mostram a arrecadação de ICMS. Os dados tem registros dos anos de 2010 a 2015.
#
# Será fornecido 1 dataset com 2 colunas, data e arrecadação de icms.

# %%
# Carrega os dados
dataframe = pd.read_csv("Arrecadacao_icms.csv")
dataframe['Data'] = pd.to_datetime(dataframe.Data, format = '%d/%m/%Y')
dataframe = dataframe.set_index('Data')

# %%
# Dados
dataframe.head()
# Out:
#             Arrecadacao
# Data
# 2010-01-01      3299311
# 2010-02-01      2415158
# 2010-03-01      2613292
# 2010-04-01      2533679
# 2010-05-01      2426702

# %%
# Refinamos os dados para o gráfico da série original
# A variável File_System é nossa variável target 
target = dataframe['Arrecadacao']

# %%
# Plot
target.plot(title = 'Total de Arrecadação de ICMS', fontsize = 14, label = 'Dados de Arrecadação') 
plt.xlabel("Data") 
plt.ylabel("Arrecadação de ICMS") 
plt.legend(loc = 'best') 
plt.show()

# %%
# Divisão em treino e teste
treino_size = int(len(target) * 0.75)
treino, teste = target[0:treino_size], target[treino_size:]
print(len(treino), len(teste))
# Out:
# 72 24

# %% [markdown]
# Para a preparação dos dados, vamos alternar entre objetos NumPy e Pandas, usando o que cada um oferece de melhor.

# %%
# Ajusta o shape, pois agora não temos um objeto pd.Series, 
# mas sim um array NumPy, que é necessário para treinar o modelo LSTM
trainset = treino.values.reshape(-1,1)
testset = teste.values.reshape(-1,1)

# %%
# Função
def performance(y_true, y_pred): 
    mse = ((y_pred - y_true) ** 2).mean()
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return( print('MSE das previsões é {}'.format(round(mse, 4))+
                  '\nRMSE das previsões é {}'.format(round(np.sqrt(mse), 4))+
                  '\nMAPE das previsões é {}'.format(round(mape, 4))))

# %% [markdown]
# ## Modelo LSTM Bidirectional

# %% [markdown]
# Redes LSTMs Bidirecionais são uma extensão das LSTMs tradicionais que podem melhorar o desempenho do modelo preditivo.
#
# Nos problemas em que todos os timesteps da sequência de entrada estão disponíveis, redes LSTMs Bidirecionais treinam duas em vez de uma rede LSTM na sequência de entrada. A primeira na sequência de entrada original e a segunda em uma cópia invertida da sequência de entrada. Isso pode fornecer um contexto adicional à rede e resultar em um aprendizado mais rápido e ainda mais completo sobre o problema.
#
# As redes neurais recorrentes bidirecionais estão realmente apenas juntando duas RNNs independentes. A sequência de entrada é alimentada em ordem de tempo normal para uma rede e em ordem inversa para outra. As saídas das duas redes são geralmente concatenadas a cada etapa do tempo, embora existam outras opções.
#
# Esse modelo é estudado em detalhes no curso <a href="https://www.datascienceacademy.com.br/course?courseid=deep-learning-ii">Deep Learning II</a>.

# %% [markdown]
# ### Preparando os Dados Para Treinamento

# %% [markdown]
# Como regra geral, sempre que você usa uma rede neural, você deve normalizar ou dimensionar seus dados. Usaremos a classe MinMaxScaler da biblioteca sklearn.preprocessing para dimensionar nossos dados entre 0 e 1. O parâmetro feature_range é usado para especificar o intervalo dos dados dimensionados e se não for especificado o intevalo será entre 0 e 1.

# %%
# Cria o scaler
scaler = MinMaxScaler()

# %%
# Treina o scaler nos dados de treino (nunca no dataset completo ou nos dados de teste)
scaler.fit(trainset)
# Out:
# MinMaxScaler()

# %%
# Aplica o mesmo scaler aos dados de treino 
# (Não precisamos aplicar aos dados de teste, pois vamos converter a saída das previsões antes de avaliar o modelo)
trainset = scaler.transform(trainset)

# %% [markdown]
# Aqui definimos os hiperparâmetros, os mesmos que usamos anteriormente em outros modelos LSTM que criamos.

# %%
# Número de repetições
n_rep = 20

# Número de epochs
num_epochs = 200

# Número de inputs (usaremos 24 séries para prever as 24 séries seguintes)
n_input = 24

# Comprimento das sequências de saída (em número de timesteps)
n_output = 24

# Aqui estamos indicando que nossa série é univariada, logo, apenas 1 recurso
n_features = 1

# Número de amostras de séries temporais em cada lote
size_batch = 10

# %% [markdown]
# O TimeseriesGenerator do Keras transforma automaticamente um conjunto de dados univariado de séries temporais em um dataset para problema de aprendizado supervisionado.
#
# https://keras.io/preprocessing/sequence/

# %%
# Generator
generator = TimeseriesGenerator(trainset, 
                                trainset, 
                                length = n_output,
                                batch_size = size_batch)

# %% [markdown]
# Podemos agora criar o modelo.
#
# Para começar a aplicação de Deep Learning ao nosso problema criaremos um modelo básico de LSTM que chamarei de LSTM Padrão.
#
# Aqui está a principal diferença dos modelos de Deep Learning para outros métodos de previsão de séries temporais. Temos que criar o modelo com cada camada da rede neural.
#
# Como trabalharemos com batches de dados da série que serão passados pela rede várias vezes, vamos criar o modelo e gerar os batches de dados a cada passada de um loop. As camadas de rede nada mais são que operações matemáticas.
#
# Nas próximas aulas ensinarei a você como definir os parâmetros da rede (como número de neurônios e dropout). Por agora, leia os comentários em cada linha de código abaixo.

# %%
# Criação e treinamento do modelo LSTM Padrão
start = time()

# Criamos uma matriz preenchida com zeros que receberá o resultado das previsões do nosso modelo
resultado = np.zeros((n_input, n_rep))

# Loop
# Vamos repetir o processo de treinamento por 20 vezes e armazenar todos os resultados, pois assim usaremos
# diferentes amostras. Ao final, tiramos a média para encontrar as previsões.
for i in range(n_rep):
    
    # O primeiro passo é criar o modelo, ou seja, um objeto da classe Sequential() do Keras
    modelo_lstm = Sequential()
    
    # Modelo Bidirectional
    modelo_lstm.add(Bidirectional(LSTM(48, activation = 'relu'), input_shape = (24, 1)))
    modelo_lstm.add(Dense(1))
    
    # Com as camadas prontas, podemos definir a função de perda, nesse caso usaremos o MSE (Mean Squared Error)
    # E indicamos o algoritmo de otimização (minimização da função de perda), em nosso caso ADAM
    modelo_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    # Aqui fazemos o treinamento gerando batches de dados
    modelo_lstm.fit_generator(generator, epochs = num_epochs)
    
    # Lista para as previsões
    pred_list = []

    # Gera um batch de dados
    batch = trainset[-n_input:].reshape((1, n_input, n_features))

    # Loop para fazer as previsões
    for j in range(n_input):   
        pred_list.append(modelo_lstm.predict(batch)[0]) 
        batch = np.append(batch[:,1:,:], [[pred_list[j]]], axis = 1)

    # Gera o dataframe com as previsões
    df_predict_modelo_lstm = pd.DataFrame(scaler.inverse_transform(pred_list),
                                      index = target[-n_input:].index, columns = ['Prediction'])

    resultado[:,i] = df_predict_modelo_lstm['Prediction']
    
print(resultado)

print ('\nTempo gasto: %s segundos' % str(time() - start))
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.1379
# Epoch 2/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0887
# Epoch 3/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0456
# Epoch 4/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0274
# Epoch 5/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0264
# Epoch 6/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0262
# Epoch 7/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0238
# Epoch 8/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0227
# Epoch 9/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0229
# Epoch 10/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0222
# Epoch 11/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 12/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0216
# Epoch 13/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0215
# Epoch 14/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 15/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 16/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 17/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0211
# Epoch 18/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0210
# Epoch 19/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 20/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0209
# Epoch 21/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0208
# Epoch 22/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0208
# Epoch 23/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0209
# Epoch 24/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0207
# Epoch 25/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0208
# Epoch 26/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0206
# Epoch 27/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0207
# Epoch 28/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0207
# Epoch 29/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 30/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0203
# Epoch 31/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0202
# Epoch 32/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0202
# Epoch 33/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0201
# Epoch 34/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0200
# Epoch 35/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0199
# Epoch 36/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0200
# Epoch 37/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0201
# Epoch 38/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0200
# Epoch 39/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0197
# Epoch 40/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0199
# Epoch 41/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0195
# Epoch 42/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0195
# Epoch 43/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0194
# Epoch 44/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0192
# Epoch 45/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0192
# Epoch 46/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0190
# Epoch 47/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0189
# Epoch 48/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0188
# Epoch 49/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0188
# Epoch 50/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0186
# Epoch 51/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0184
# Epoch 52/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0182
# Epoch 53/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0182
# Epoch 54/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0181
# Epoch 55/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0179
# Epoch 56/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0177
# Epoch 57/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0174
# Epoch 58/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0172
# Epoch 59/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0170
# Epoch 60/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0170
# Epoch 61/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0166
# Epoch 62/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0164
# Epoch 63/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0162
# Epoch 64/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0162
# Epoch 65/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0158
# Epoch 66/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0158
# Epoch 67/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0145
# Epoch 68/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0140
# Epoch 69/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0128
# Epoch 70/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0351
# Epoch 71/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0411
# Epoch 72/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0327
# Epoch 73/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0377
# Epoch 74/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0296
# Epoch 75/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0166
# Epoch 76/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0172
# Epoch 77/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0174
# Epoch 78/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0161
# Epoch 79/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0157
# Epoch 80/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0157
# Epoch 81/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0155
# Epoch 82/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0153
# Epoch 83/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0154
# Epoch 84/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0152
# Epoch 85/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0151
# Epoch 86/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0150
# Epoch 87/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0149
# Epoch 88/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0148
# Epoch 89/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0147
# Epoch 90/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0147
# Epoch 91/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0145
# Epoch 92/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0145
# Epoch 93/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0144
# Epoch 94/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0142
# Epoch 95/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0142
# Epoch 96/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0141
# Epoch 97/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0140
# Epoch 98/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0139
# Epoch 99/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0138
# Epoch 100/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0137
# Epoch 101/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0136
# Epoch 102/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0135
# Epoch 103/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0134
# Epoch 104/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0133
# Epoch 105/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0132
# Epoch 106/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0130
# Epoch 107/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0129
# Epoch 108/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0128
# Epoch 109/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0127
# Epoch 110/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0125
# Epoch 111/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0124
# Epoch 112/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0123
# Epoch 113/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0121
# Epoch 114/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0120
# Epoch 115/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0119
# Epoch 116/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0116
# Epoch 117/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0115
# Epoch 118/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0115
# Epoch 119/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0111
# Epoch 120/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0108
# Epoch 121/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0108
# Epoch 122/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0103
# Epoch 123/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0101
# Epoch 124/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0098
# Epoch 125/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0095
# Epoch 126/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0094
# Epoch 127/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0087
# Epoch 128/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0084
# Epoch 129/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0080
# Epoch 130/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0079
# Epoch 131/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0076
# Epoch 132/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0072
# Epoch 133/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0070
# Epoch 134/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0076
# Epoch 135/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0069
# Epoch 136/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0073
# Epoch 137/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0071
# Epoch 138/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0077
# Epoch 139/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0057
# Epoch 140/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0069
# Epoch 141/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0067
# Epoch 142/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0064
# Epoch 143/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0069
# Epoch 144/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0064
# Epoch 145/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0076
# Epoch 146/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0073
# Epoch 147/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0067
# Epoch 148/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0057
# Epoch 149/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0050
# Epoch 150/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0072
# Epoch 151/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0051
# Epoch 152/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0071
# Epoch 153/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0061
# Epoch 154/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0064
# Epoch 155/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0062
# Epoch 156/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 157/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0055
# Epoch 158/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0054
# Epoch 159/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0060
# Epoch 160/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0048
# Epoch 161/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0042
# Epoch 162/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0039
# Epoch 163/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0049
# Epoch 164/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0043
# Epoch 165/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0116
# Epoch 166/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0078
# Epoch 167/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0084
# Epoch 168/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0084
# Epoch 169/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0082
# Epoch 170/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0079
# Epoch 171/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0076
# Epoch 172/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0075
# Epoch 173/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0074
# Epoch 174/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0073
# Epoch 175/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0074
# Epoch 176/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0074
# Epoch 177/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 178/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0070
# Epoch 179/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0065
# Epoch 180/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 181/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0064
# Epoch 182/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0064
# Epoch 183/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 184/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 185/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0060
# Epoch 186/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0059
# Epoch 187/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0070
# Epoch 188/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0078
# Epoch 189/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0066
# Epoch 190/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0069
# Epoch 191/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0061
# Epoch 192/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0055
# Epoch 193/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0052
# Epoch 194/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0052
# Epoch 195/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0054
# Epoch 196/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0052
# Epoch 197/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0049
# Epoch 198/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0052
# Epoch 199/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0057
# Epoch 200/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0057
# Epoch 1/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.2256
# Epoch 2/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1673
# Epoch 3/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.1241
# Epoch 4/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0880
# Epoch 5/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0538
# Epoch 6/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0315
# Epoch 7/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0259
# Epoch 8/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0263
# Epoch 9/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0227
# Epoch 10/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0226
# Epoch 11/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0227
# Epoch 12/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0224
# Epoch 13/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0221
# Epoch 14/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0219
# Epoch 15/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0219
# Epoch 16/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0218
# Epoch 17/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0217
# Epoch 18/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0217
# Epoch 19/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0216
# Epoch 20/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 21/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0214
# Epoch 22/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 23/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 24/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0214
# Epoch 25/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 26/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0211
# Epoch 27/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0211
# Epoch 28/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0210
# Epoch 29/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0208
# Epoch 30/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0209
# Epoch 31/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0210
# Epoch 32/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 33/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0209
# Epoch 34/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0207
# Epoch 35/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0205
# Epoch 36/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0204
# Epoch 37/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0203
# Epoch 38/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0202
# Epoch 39/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0201
# Epoch 40/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0201
# Epoch 41/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0201
# Epoch 42/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0197
# Epoch 43/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0197
# Epoch 44/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0196
# Epoch 45/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0194
# Epoch 46/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0192
# Epoch 47/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0194
# Epoch 48/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0196
# Epoch 49/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0185
# Epoch 50/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0184
# Epoch 51/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0177
# Epoch 52/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0177
# Epoch 53/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0168
# Epoch 54/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0161
# Epoch 55/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0168
# Epoch 56/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0255
# Epoch 57/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0183
# Epoch 58/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0184
# Epoch 59/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0184
# Epoch 60/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0188
# Epoch 61/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0186
# Epoch 62/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0184
# Epoch 63/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0186
# Epoch 64/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0183
# Epoch 65/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0182
# Epoch 66/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0180
# Epoch 67/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0180
# Epoch 68/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0177
# Epoch 69/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0175
# Epoch 70/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0177
# Epoch 71/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0174
# Epoch 72/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0175
# Epoch 73/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0177
# Epoch 74/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0171
# Epoch 75/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0166
# Epoch 76/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0166
# Epoch 77/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0161
# Epoch 78/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0162
# Epoch 79/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0153
# Epoch 80/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0152
# Epoch 81/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0145
# Epoch 82/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0135
# Epoch 83/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0135
# Epoch 84/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0132
# Epoch 85/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0152
# Epoch 86/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0177
# Epoch 87/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0146
# Epoch 88/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0147
# Epoch 89/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0146
# Epoch 90/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0148
# Epoch 91/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0142
# Epoch 92/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0138
# Epoch 93/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0130
# Epoch 94/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0120
# Epoch 95/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0113
# Epoch 96/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0100
# Epoch 97/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0094
# Epoch 98/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0084
# Epoch 99/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0189
# Epoch 100/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0111
# Epoch 101/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0142
# Epoch 102/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0139
# Epoch 103/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0146
# Epoch 104/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0142
# Epoch 105/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0135
# Epoch 106/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0128
# Epoch 107/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0126
# Epoch 108/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0124
# Epoch 109/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0120
# Epoch 110/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0116
# Epoch 111/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0112
# Epoch 112/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0105
# Epoch 113/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0099
# Epoch 114/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0092
# Epoch 115/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0079
# Epoch 116/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0074
# Epoch 117/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0066
# Epoch 118/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0096
# Epoch 119/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0087
# Epoch 120/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0108
# Epoch 121/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0070
# Epoch 122/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0071
# Epoch 123/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0099
# Epoch 124/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0077
# Epoch 125/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0087
# Epoch 126/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0084
# Epoch 127/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0089
# Epoch 128/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0078
# Epoch 129/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0067
# Epoch 130/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0061
# Epoch 131/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0056
# Epoch 132/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0049
# Epoch 133/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0046
# Epoch 134/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0048
# Epoch 135/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0042
# Epoch 136/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0039
# Epoch 137/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0038
# Epoch 138/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0037
# Epoch 139/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0048
# Epoch 140/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0043
# Epoch 141/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0043
# Epoch 142/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0063
# Epoch 143/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0060
# Epoch 144/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0106
# Epoch 145/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0217
# Epoch 146/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0163
# Epoch 147/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0133
# Epoch 148/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0155
# Epoch 149/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0131
# Epoch 150/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0113
# Epoch 151/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0113
# Epoch 152/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0105
# Epoch 153/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0097
# Epoch 154/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0099
# Epoch 155/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0092
# Epoch 156/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0085
# Epoch 157/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0077
# Epoch 158/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0071
# Epoch 159/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0062
# Epoch 160/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0055
# Epoch 161/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0048
# Epoch 162/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0046
# Epoch 163/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0042
# Epoch 164/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0042
# Epoch 165/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0039
# Epoch 166/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0037
# Epoch 167/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0037
# Epoch 168/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0036
# Epoch 169/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0038
# Epoch 170/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0038
# Epoch 171/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0038
# Epoch 172/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0039
# Epoch 173/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0045
# Epoch 174/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0052
# Epoch 175/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0057
# Epoch 176/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0045
# Epoch 177/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0057
# Epoch 178/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0043
# Epoch 179/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0041
# Epoch 180/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0045
# Epoch 181/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0042
# Epoch 182/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0038
# Epoch 183/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0038
# Epoch 184/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0036
# Epoch 185/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0035
# Epoch 186/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0036
# Epoch 187/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0035
# Epoch 188/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0039
# Epoch 189/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0040
# Epoch 190/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0037
# Epoch 191/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0043
# Epoch 192/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0041
# Epoch 193/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0043
# Epoch 194/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0040
# Epoch 195/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0039
# Epoch 196/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0037
# Epoch 197/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0037
# Epoch 198/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0041
# Epoch 199/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0039
# Epoch 200/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0049
# Epoch 1/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1808
# Epoch 2/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1250
# Epoch 3/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0884
# Epoch 4/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0513
# Epoch 5/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0275
# Epoch 6/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0244
# Epoch 7/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0287
# Epoch 8/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0238
# Epoch 9/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0219
# Epoch 10/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0225
# Epoch 11/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0223
# Epoch 12/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0219
# Epoch 13/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0216
# Epoch 14/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0217
# Epoch 15/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0217
# Epoch 16/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0216
# Epoch 17/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0216
# Epoch 18/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0215
# Epoch 19/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 20/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0215
# Epoch 21/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0214
# Epoch 22/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 23/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0214
# Epoch 24/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0214
# Epoch 25/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 26/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0215
# Epoch 27/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 28/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 29/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 30/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0211
# Epoch 31/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0211
# Epoch 32/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0210
# Epoch 33/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0209
# Epoch 34/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0209
# Epoch 35/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0208
# Epoch 36/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0208
# Epoch 37/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0207
# Epoch 38/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0207
# Epoch 39/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0207
# Epoch 40/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0207
# Epoch 41/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0205
# Epoch 42/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0204
# Epoch 43/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0205
# Epoch 44/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 45/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0203
# Epoch 46/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0204
# Epoch 47/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0206
# Epoch 48/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0203
# Epoch 49/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0201
# Epoch 50/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0202
# Epoch 51/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0203
# Epoch 52/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0200
# Epoch 53/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0199
# Epoch 54/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0197
# Epoch 55/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0198
# Epoch 56/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0198
# Epoch 57/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0195
# Epoch 58/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0192
# Epoch 59/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0191
# Epoch 60/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0189
# Epoch 61/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0190
# Epoch 62/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0187
# Epoch 63/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0185
# Epoch 64/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0183
# Epoch 65/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0185
# Epoch 66/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0179
# Epoch 67/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0179
# Epoch 68/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0173
# Epoch 69/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0171
# Epoch 70/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0164
# Epoch 71/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0165
# Epoch 72/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0168
# Epoch 73/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0153
# Epoch 74/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0139
# Epoch 75/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0139
# Epoch 76/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0164
# Epoch 77/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0178
# Epoch 78/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0174
# Epoch 79/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0168
# Epoch 80/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0173
# Epoch 81/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0174
# Epoch 82/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0169
# Epoch 83/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0167
# Epoch 84/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0166
# Epoch 85/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0164
# Epoch 86/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0162
# Epoch 87/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0159
# Epoch 88/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0157
# Epoch 89/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0156
# Epoch 90/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0153
# Epoch 91/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0149
# Epoch 92/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0145
# Epoch 93/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0142
# Epoch 94/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0135
# Epoch 95/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0138
# Epoch 96/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0134
# Epoch 97/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0130
# Epoch 98/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0123
# Epoch 99/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0121
# Epoch 100/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0135
# Epoch 101/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0129
# Epoch 102/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0116
# Epoch 103/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0107
# Epoch 104/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0114
# Epoch 105/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0107
# Epoch 106/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0103
# Epoch 107/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0103
# Epoch 108/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0113
# Epoch 109/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0137
# Epoch 110/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0106
# Epoch 111/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0107
# Epoch 112/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0096
# Epoch 113/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0090
# Epoch 114/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0086
# Epoch 115/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0082
# Epoch 116/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0087
# Epoch 117/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0103
# Epoch 118/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0114
# Epoch 119/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0093
# Epoch 120/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0084
# Epoch 121/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0084
# Epoch 122/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0082
# Epoch 123/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0088
# Epoch 124/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0090
# Epoch 125/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0098
# Epoch 126/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0096
# Epoch 127/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0093
# Epoch 128/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0087
# Epoch 129/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0079
# Epoch 130/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0073
# Epoch 131/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0076
# Epoch 132/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0090
# Epoch 133/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0095
# Epoch 134/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0081
# Epoch 135/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0083
# Epoch 136/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0083
# Epoch 137/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0076
# Epoch 138/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0072
# Epoch 139/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0080
# Epoch 140/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0075
# Epoch 141/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0090
# Epoch 142/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0103
# Epoch 143/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0089
# Epoch 144/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0085
# Epoch 145/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0074
# Epoch 146/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0072
# Epoch 147/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0068
# Epoch 148/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0076
# Epoch 149/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0076
# Epoch 150/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0071
# Epoch 151/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0065
# Epoch 152/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0067
# Epoch 153/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0064
# Epoch 154/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0064
# Epoch 155/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0067
# Epoch 156/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 157/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0066
# Epoch 158/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0073
# Epoch 159/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0073
# Epoch 160/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0065
# Epoch 161/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0063
# Epoch 162/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0065
# Epoch 163/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0064
# Epoch 164/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0068
# Epoch 165/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0068
# Epoch 166/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0062
# Epoch 167/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0068
# Epoch 168/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0069
# Epoch 169/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0065
# Epoch 170/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0069
# Epoch 171/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0076
# Epoch 172/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0060
# Epoch 173/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0066
# Epoch 174/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0062
# Epoch 175/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0061
# Epoch 176/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0060
# Epoch 177/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0058
# Epoch 178/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 179/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0064
# Epoch 180/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0059
# Epoch 181/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 182/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0055
# Epoch 183/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0059
# Epoch 184/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0061
# Epoch 185/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0055
# Epoch 186/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0065
# Epoch 187/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0072
# Epoch 188/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0064
# Epoch 189/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0063
# Epoch 190/200
# ...
# Epoch 109/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0135
# Epoch 110/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0114
# Epoch 111/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0114
# Epoch 112/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0105
# Epoch 113/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0095
# Epoch 114/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0090
# Epoch 115/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0085
# Epoch 116/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0073
# Epoch 117/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0074
# Epoch 118/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0073
# Epoch 119/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0076
# Epoch 120/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0065
# Epoch 121/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0073
# Epoch 122/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0061
# Epoch 123/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0077
# Epoch 124/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0075
# Epoch 125/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0076
# Epoch 126/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0137
# Epoch 127/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0183
# Epoch 128/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0125
# Epoch 129/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0129
# Epoch 130/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0149
# Epoch 131/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0128
# Epoch 132/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0114
# Epoch 133/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0110
# Epoch 134/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0098
# Epoch 135/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0096
# Epoch 136/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0084
# Epoch 137/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0082
# Epoch 138/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0086
# Epoch 139/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0074
# Epoch 140/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0079
# Epoch 141/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0073
# Epoch 142/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0082
# Epoch 143/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0090
# Epoch 144/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0079
# Epoch 145/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0075
# Epoch 146/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0072
# Epoch 147/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0070
# Epoch 148/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0071
# Epoch 149/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0067
# Epoch 150/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0073
# Epoch 151/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0065
# Epoch 152/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0069
# Epoch 153/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 154/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0067
# Epoch 155/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0068
# Epoch 156/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0064
# Epoch 157/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0067
# Epoch 158/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0067
# Epoch 159/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0063
# Epoch 160/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0058
# Epoch 161/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0061
# Epoch 162/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0063
# Epoch 163/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0061
# Epoch 164/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0058
# Epoch 165/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0059
# Epoch 166/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0055
# Epoch 167/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0061
# Epoch 168/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0059
# Epoch 169/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0060
# Epoch 170/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0054
# Epoch 171/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0059
# Epoch 172/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0064
# Epoch 173/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0064
# Epoch 174/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0056
# Epoch 175/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0054
# Epoch 176/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0051
# Epoch 177/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0049
# Epoch 178/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0050
# Epoch 179/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0056
# Epoch 180/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0048
# Epoch 181/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0053
# Epoch 182/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0053
# Epoch 183/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0049
# Epoch 184/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0045
# Epoch 185/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0049
# Epoch 186/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0058
# Epoch 187/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0048
# Epoch 188/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0043
# Epoch 189/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0043
# Epoch 190/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0045
# Epoch 191/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0044
# Epoch 192/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0044
# Epoch 193/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0045
# Epoch 194/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0047
# Epoch 195/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0052
# Epoch 196/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0057
# Epoch 197/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0055
# Epoch 198/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0043
# Epoch 199/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0043
# Epoch 200/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0040
# [[5976495.49581861 5902214.58719873 5961065.59357357 5883610.11942911
#   5795970.96586943 5136493.5238595  5687767.82024193 4704018.34155822
#   6086318.96339798 5912526.41862202 6005934.01444435 5740568.04946136
#   5941218.0513258  5752574.09047866 6022315.04487419 5818638.25276947
#   5989319.50707483 5878993.8438139  5788563.37932873 5872294.69759274]
#  [4487288.8669579  4359416.99118137 4578770.37814665 4312317.92442036
#   4108775.29144907 4047239.6006242  4197284.07652593 4164068.07722521
#   4472082.22953939 4367402.66342092 4471967.49344468 4434720.71301556
#   4326474.51632285 4259833.06928325 4240674.14384127 4505539.11456776
#   4393376.27212882 4352068.87518191 4249001.02080226 4182476.31223249]
#  [4510611.93171167 4407409.71796107 4605947.81478024 4358600.02213001
#   4184274.44509554 4010068.81033111 4248627.37760377 4138349.37087083
#   4539693.02637744 4421121.58234811 4517583.40094995 4484141.13326001
#   4390387.32677841 4301903.77162814 4120698.03366113 4538639.57682371
#   4406946.36835694 4379473.18091726 4304509.66261697 4241194.96161151]
#  [4300062.58769989 4133988.9987967  4322333.80480003 4101318.8469553
#   3938513.23437631 3835828.73471451 4023399.22225666 4008852.36744213
#   4264542.2551043  4141039.76208997 4251115.52893519 4223934.48802638
#   4126211.17309523 4055143.17548358 3868944.71537769 4279474.96760559
#   4110393.4107883  4117856.46311998 4043308.53777707 3958206.69385815]
#  [4126658.90417337 3905725.54311502 4090321.2020514  3882441.92515123
#   3744339.31414402 3720669.23778093 3833882.62632966 3909342.73366117
#   4021244.4663837  3891714.22352791 4030417.14659786 4010560.59366202
#   3900092.96200466 3849886.00881076 3696088.18085432 4062399.28234601
#   3879140.70939994 3899660.8494525  3824184.92335749 3715326.6005888 ]
#  [4109703.59255743 3921701.29281938 4096607.4585216  3889823.58093405
#   3789838.88365448 3737629.95580971 3867282.44366693 3895228.69223011
#   4026405.78850818 3896089.81365299 4047262.5278194  4011928.41611052
#   3925333.90165401 3867398.68154299 3683472.81708622 4047773.1334765
#   3916977.08918488 3906239.15233481 3840629.72943509 3735686.7508688 ]
#  [4078882.73426354 3913388.43248427 4081310.31374741 3852393.5831809
#   3792080.64272666 3751613.44238257 3885268.7782352  3877378.21881413
#   3998052.55720067 3879288.48468423 4023110.68000102 3983442.52745092
#   3919223.65395737 3855849.88288569 3677162.53211451 4011100.53411472
#   3928235.94392395 3890020.31429017 3834888.71971166 3735539.57629704]
#  [4013361.81634438 3849023.6859628  4005916.98562634 3752599.51201332
#   3726887.3133781  3752297.95431936 3852440.53887761 3850071.9293412
#   3896177.11720848 3798284.00086665 3945508.83223486 3894460.88148808
#   3848829.25533807 3786600.64260089 3657472.37655163 3924666.81038082
#   3872605.15722656 3812196.80359757 3770391.21571934 3673737.06898665]
#  [3944689.26009583 3785348.35719717 3925786.13807619 3653386.12963223
#   3642708.16391718 3774632.8469485  3808571.70366967 3838409.19553924
#   3780408.19740534 3701123.55358338 3873751.91746116 3785267.56136084
#   3784019.98153865 3707239.90852416 3658476.06708348 3831484.5818789
#   3816792.55486774 3722549.46802413 3702739.27007246 3607174.11505198]
#  [3914951.28627002 3789104.61269581 3905089.48865628 3623634.53965557
#   3604326.83774173 3858411.12090921 3802578.69503665 3874314.78510904
#   3729468.9756279  3657775.33590817 3852467.27058554 3740576.25056994
#   3789469.34532499 3683106.28231943 3721863.85478103 3797796.62276101
#   3826539.61638677 3689139.33845496 3691875.58406448 3604788.38520825]
#  [3985327.96386945 3932395.47777295 4042700.91704512 3776325.45464242
#   3693456.1588701  4049606.00754797 3934287.72226691 3986215.11616898
#   3865727.39914417 3769133.2235465  3980488.4234277  3849470.01537836
#   3970374.12631059 3802202.94934428 3901910.71814394 3900094.36366725
#   3995294.98629606 3820098.07572556 3886021.2708075  3742705.67639756]
#  [4129444.20797348 4060808.99602103 4211156.73163557 4004315.68623817
#   3941156.36954248 4410057.05811501 4026810.56863987 4151411.86500454
#   4051687.7768476  3933140.56155729 4140077.62084198 4077433.0146724
#   4049701.62096024 3999149.55841339 4386115.86015987 4121837.98582029
#   4109898.62389469 3991241.1778537  4024093.94630659 3936724.01208258]
#  [6017671.13648224 6088143.12713766 6100630.33889771 5825743.48066616
#   5968392.68463421 5773502.31458187 5931244.62129879 4761755.62688804
#   6252759.58766174 6011643.5868783  6069064.89741325 5781257.1129694
#   6026438.73620844 5919745.38142586 6810026.19184589 5898253.88919973
#   6064481.4607501  5962525.32504034 5929531.78961611 5963125.63710308]
#  [4534235.95344687 4508576.51739621 4643886.01534033 4311676.76390505
#   4273539.32701993 4389438.40120625 4440547.62463188 4266463.33380008
#   4538315.99300337 4425592.08505416 4542405.64396048 4467663.38811159
#   4339768.48502111 4417890.54984498 4613436.89798856 4603826.49857187
#   4489973.65152669 4410714.83834386 4397372.01169252 4343718.37019444]
#  [4672122.70841551 4719430.22242713 4806799.45581985 4504579.57640743
#   4481322.3897953  4415527.1464839  4635597.98445678 4313766.24234891
#   4769460.76637244 4631085.83234811 4735790.02768064 4637948.97309208
#   4579672.24790335 4601595.2519691  4599833.36209583 4777988.28132105
#   4659383.59786463 4584846.78570366 4589093.22263312 4559326.51472425]
#  [4369117.29724121 4300077.20503831 4360655.46019673 4151763.08160162
#   4085562.25720847 4157802.64545631 4266953.71546841 4173812.03506279
#   4320793.17737818 4191386.48106766 4312252.44675374 4263799.3739326
#   4155417.21596885 4229116.63485217 4204164.43769598 4425839.17814469
#   4217506.86387229 4197895.20141435 4186545.13848829 4132664.42765093]
#  [4353374.6240015  4316721.5477972  4362609.17760706 4196098.87068892
#   4135381.04998422 4139411.63087511 4282591.06377649 4175054.70906591
#   4337218.86077332 4192989.18211842 4333320.23640323 4283660.73256874
#   4202693.69316602 4253693.58690977 4165901.65212798 4427187.97802949
#   4239330.75036931 4211194.97700047 4197144.71121716 4149957.53995061]
#  [4361698.29716229 4364859.24653602 4400812.89310884 4248607.95456505
#   4209685.38639307 4134906.68731689 4335451.16401219 4179885.03858209
#   4380489.38629365 4241490.51218009 4363188.06425595 4326679.35929823
#   4284038.38051748 4304550.91154456 4173334.26835775 4447536.31429625
#   4308421.30242538 4256852.13343334 4235113.54811668 4206235.6945262 ]
#  [4278162.01023555 4278865.64485478 4308625.1442132  4161292.18458819
#   4127456.2499485  4068472.58622158 4270965.07355809 4142631.65031505
#   4273623.62701273 4152730.22878742 4259394.14865565 4242333.51210809
#   4229410.38328314 4221460.35332084 4100525.70616794 4348984.61677551
#   4241625.47226357 4172714.53325629 4165497.17235255 4118736.90746284]
#  [4116066.33975744 4070246.08987057 4092806.95053267 3968224.17613792
#   3939944.93259132 3980464.5951637  4083849.02505076 4086219.03624976
#   4012227.97142935 3934027.41350055 4033022.33675539 4070019.52112508
#   4024269.75484264 4028808.738778   3974499.7199012  4163149.58775496
#   4042780.81181264 3969217.75467539 3967936.93542612 3910508.01586568]
#  [4235553.06945682 4299115.86474037 4291573.31811619 4149503.40127206
#   4147156.81786203 4091169.40815473 4287287.03392172 4151350.39208817
#   4212983.09798789 4154205.17830515 4233160.23118138 4224239.64999557
#   4283434.86465454 4217289.80640864 4138364.58892179 4276013.66196299
#   4270975.28567123 4148558.28021264 4158666.87056065 4145011.27291465]
#  [4069376.55847216 4094291.91192603 4070868.52817845 3942327.55875361
#   3906094.1803757  4009604.55965817 4091899.57424438 4092514.10317051
#   3936891.81111813 3919607.509269   4029936.07597387 4013148.2630372
#   4110689.76230693 3993096.17817032 4039059.59787869 4067046.39453816
#   4085676.4927094  3940215.85394585 3975784.44378197 3928599.3750093 ]
#  [4006538.52286541 4042247.27896035 4028539.11896729 3959715.28327799
#   3837108.25241995 4052984.51497912 4016469.60265851 4112011.1296525
#   3870120.40993285 3855578.56105614 3988649.40360951 3989247.21270335
#   4097976.8828702  3943856.67251849 4086180.6907661  4024022.6617521
#   4071773.90209162 3904958.63344181 3993622.00187838 3879522.46221769]
#  [4367787.11944509 4511498.3831799  4528471.51593447 4509457.16197658
#   4422059.49485707 4367272.70927525 4421042.88900566 4286017.92856693
#   4438799.95162201 4385982.30173898 4491431.38061833 4502972.67036891
#   4517557.37007332 4446695.91745591 4834225.58744407 4496854.01269674
#   4523649.79663134 4410732.65948248 4427483.72883558 4423640.77049398]]
#
# Tempo gasto: 3471.4960153102875 segundos

# %% [markdown]
# Agora calculamos o erro modelo.

# %%
# Vamos criar uma matriz com as mesmas dimensões da matriz de resultado usada no treinamento
resultado_final = np.zeros((resultado.shape[0],1))

# %%
# Loop para gerar as previsões finais
for i in range(resultado.shape[0]):
    resultado_final[i] = np.mean(resultado[i,:])

# %%
# Ajustamos o shape
resultado_final = resultado_final.reshape((24,))

# %%
# Previsões finais
resultado_final
# Out:
# array([5792845.03803666, 4325538.88151559, 4355509.07579069,
#        4105223.44841515, 3899704.87166964, 3910650.6850934 ,
#        3898411.57762333, 3834176.49490314, 3767227.94859641,
#        3757863.91140334, 3894191.80231867, 4087813.16212904,
#        5957796.84633495, 4447952.11750301, 4613758.52949315,
#        4235156.21372468, 4247776.82872155, 4288191.8271461 ,
#        4208175.36026908, 4023414.48536106, 4205780.60471946,
#        4015836.43662589, 3988056.15993097, 4465681.66748513])

# %%
testseta = testset.reshape((24,))
testseta
# Out:
# array([6360023, 4408531, 4748431, 4278694, 4273985, 4350053, 4283739,
#        4816248, 4374269, 4758541, 4661014, 5206376, 6974641, 5075192,
#        4741150, 4924371, 4686747, 4062240, 4775886, 4798030, 5522158,
#        4817980, 4340612, 4706995], dtype=int64)

# %%
res = np.zeros((resultado.shape[0],1))
for i in range(resultado.shape[0]):
    res[i] = resultado_final[i] - testset[i]
    print('test =  %.4f  resultado = %.4f   Erro = %.4f' % (testset[i], resultado_final[i], res[i]))
# Out:
# test =  6360023.0000  resultado = 5792845.0380   Erro = -567177.9620
# test =  4408531.0000  resultado = 4325538.8815   Erro = -82992.1185
# test =  4748431.0000  resultado = 4355509.0758   Erro = -392921.9242
# test =  4278694.0000  resultado = 4105223.4484   Erro = -173470.5516
# test =  4273985.0000  resultado = 3899704.8717   Erro = -374280.1283
# test =  4350053.0000  resultado = 3910650.6851   Erro = -439402.3149
# test =  4283739.0000  resultado = 3898411.5776   Erro = -385327.4224
# test =  4816248.0000  resultado = 3834176.4949   Erro = -982071.5051
# test =  4374269.0000  resultado = 3767227.9486   Erro = -607041.0514
# test =  4758541.0000  resultado = 3757863.9114   Erro = -1000677.0886
# test =  4661014.0000  resultado = 3894191.8023   Erro = -766822.1977
# test =  5206376.0000  resultado = 4087813.1621   Erro = -1118562.8379
# test =  6974641.0000  resultado = 5957796.8463   Erro = -1016844.1537
# test =  5075192.0000  resultado = 4447952.1175   Erro = -627239.8825
# test =  4741150.0000  resultado = 4613758.5295   Erro = -127391.4705
# test =  4924371.0000  resultado = 4235156.2137   Erro = -689214.7863
# test =  4686747.0000  resultado = 4247776.8287   Erro = -438970.1713
# test =  4062240.0000  resultado = 4288191.8271   Erro = 225951.8271
# test =  4775886.0000  resultado = 4208175.3603   Erro = -567710.6397
# test =  4798030.0000  resultado = 4023414.4854   Erro = -774615.5146
# test =  5522158.0000  resultado = 4205780.6047   Erro = -1316377.3953
# test =  4817980.0000  resultado = 4015836.4366   Erro = -802143.5634
# test =  4340612.0000  resultado = 3988056.1599   Erro = -352555.8401
# test =  4706995.0000  resultado = 4465681.6675   Erro = -241313.3325

# %%
# Calculamos e imprimos a performance do modelo
modelo_lstm_performance = performance(testset, resultado_final)
modelo_lstm_performance
# Out:
# MSE das previsões é 1028913561238.2358
# RMSE das previsões é 1014353.7653
# MAPE das previsões é 15.0767

# %% [markdown]
# Hummm....O resultado não foi muito bom!

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(target.index, target.values, label = 'Valores Observados', color = 'Blue')
plt.plot(teste, label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(target[72:].index, resultado_final, label = 'Previsões', color = 'Red')

plt.title('Previsões Com Modelo LSTM Bidirecional')
plt.xlabel('Data')
plt.ylabel('Arrecadação')
plt.legend(loc = 'upper left')
plt.show()

# %%
# Plot
plt.figure(figsize = (20, 6))
plt.plot(teste, label = 'Dados de Teste', color = 'green')
plt.plot(target[72:].index, resultado_final, label = 'Previsões', color = 'Red')
plt.title('Previsões Com Modelo LSTM Bidirecional')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# Vamos fazer o Forecasting para 41 dias de horizonte de previsão. A função DateOffset() vai nos ajudar a criar as datas.

# %% [markdown]
# Vejamos qual é a última data da nossa série original:

# %%
# Última data da série
target.index[-1]
# Out:
# Timestamp('2017-12-01 00:00:00')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [target.index[-1] + DateOffset(months = x) for x in range(0, 25)]

# %%
# Visualiza as datas criadas
#datas_para_prever_forecasting

# %%
# Nossa série original é um objeto do tipo pd.Series
#type(arrecadacao_icms)

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pd.DataFrame(target)

# %%
# Visualiza os dados
#df_original.head()

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
#data_futuras

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index = data_futuras[-n_input:].index, columns = ['Prediction'])

# %%
# Concatenamos a série original com os valores de forecasting de 41 dias além da série
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
df_forecasting
# Out:
#             Arrecadacao    Prediction
# 2010-01-01    3299311.0           NaN
# 2010-02-01    2415158.0           NaN
# 2010-03-01    2613292.0           NaN
# 2010-04-01    2533679.0           NaN
# 2010-05-01    2426702.0           NaN
# ...                 ...           ...
# 2019-08-01          NaN  3.910508e+06
# 2019-09-01          NaN  4.145011e+06
# 2019-10-01          NaN  3.928599e+06
# 2019-11-01          NaN  3.879522e+06
# 2019-12-01          NaN  4.423641e+06
#
# [120 rows x 2 columns]

# %% [markdown]
# ### Previsão x Forecasting

# %% [markdown]
# Esse dataframe acima é para não restar qualquer dúvida do que estamos fazendo.
#
# Nas **previsões** do modelo, usamos os dados de teste, 24 meses que correspondem aos 24 últimos registros da série original (2017-01-01 a 2017-12-01. Fazemos isso para poder calcular a precisão do modelo, comparando as previsões com os valores reais. Esse é o padrão em Machine Learning.
#
# No **forecasting**, criamos 24 meses após a última data da série original. Obviamente, não temos dados históricos para esses meses e o que queremos é exatamente a previsão de vendas. O forecasting significa usar o modelo treinado e prever valores sobre novas datas.
#
# Bingo!

# %% [markdown]
# Vamos colocar o forecasting em um Plot.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(target.index, target.values, label = 'Valores Observados', color = 'Blue')
plt.plot(teste, label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(df_forecasting.index, df_forecasting['Prediction'], label = 'Forecasting', color = 'Red')

plt.title('Forecasting Com Modelo LSTM Bidirecional')
plt.xlabel('Data')
plt.ylabel('Arrecadação')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# Por que a linha vermelha do forecast é quase uma linha reta? Porque nosso modelo fez o que pedimos a ele. Aprendeu sobre as previsões das médias mensais de vendas. O maior problema nesse caso é que não capturamos os valores altos e baixos, mas somente a média. Por isso trabalhar com séries mensais é muito complicado e o ideal é mesmo usar séries diárias, como usaremos nas aulas finais do curso.
#
# Mas não acabou. Vamos tentar otimizar os hiperparâmetros.

# %% [markdown]
# ## Grid Search

# %% [markdown]
# Grid Search é o processo de executar o ajuste de hiperparâmetros para determinar os valores ideais para um modelo. Isso é significativo, pois o desempenho de todo o modelo é baseado nos valores de hiperparâmetros especificados.
#
# Se você trabalha com Machine Learning, sabe como é um difícil estipular valores para hiperparâmetros. Encontrar a combinação ideal é muito complicado e o Grid Search é uma forma de automatizar o processo.
#
# Vamos criar algumas funções e então testar diversas combinações de hiperpaâmetros. Leia os comentários para compreender o que está sendo feito em cada etapa.

# %% [markdown]
# **Tratando a Série Como um Dataset de Aprendizagem Supervisionada**
#
# Precisamos ser capazes de enquadrar a série univariada de observações como um problema de aprendizado supervisionado, para que possamos usar Grid Search.
#
# Um enquadramento de aprendizado supervisionado de uma série significa que os dados precisam ser divididos em vários exemplos com os quais o modelo aprende e generaliza.
#
# Cada amostra deve ter um componente de entrada e um componente de saída.
#
# O componente de entrada será um número de observações anteriores, como três anos ou 36 etapas de tempo.
#
# O componente de saída será o total de vendas no próximo mês, porque estamos interessados em desenvolver um modelo para fazer previsões em uma etapa.
#
# Podemos implementar isso usando a função shift() no DataFrame do pandas. Isso nos permite deslocar uma coluna para baixo (para frente no tempo) ou para trás (para trás no tempo). Podemos tomar a série como uma coluna de dados e, em seguida, criar várias cópias da coluna, avançar ou retroceder no tempo, a fim de criar as amostras com os elementos de entrada e saída necessários.
#
# Quando uma série é alterada para baixo, os valores de NaN são introduzidos porque não temos valores além do início da série e então valores NaN devem ser removidos.

# %%
# Transforma a série em formato para aprendizagem supervisionada com dados de entrada e saída
# Como temos uma série temporal, o que fazemos é pegar um pasos no tempo da série 
# (por exemplo a venda média de Janeiro) e chamar de x e o próximo passo de tempo (venda média de Fevereiro) 
# chamamos de y. E fazemos isso em toda a série, por isso o shift (deslocamento) no código abaixo.

def transforma_serie(dados, num_input = 1, num_output = 1):
    
    # Converte os dados em formato dataframe do Pandas
    df = pd.DataFrame(dados)
    
    # Lista de colunas
    cols = list()
    
    # Loop para definir os dados de entrada
    for i in range(num_input, 0, -1):
        cols.append(df.shift(i))
        
    # Loop para definir os dados de saída    
    for i in range(0, num_output):
        cols.append(df.shift(-i))
    
    # Concatena entrada e saída em um único dataframe
    dataset_final = pd.concat(cols, axis = 1)
    
    # Remove valores NA
    dataset_final.dropna(inplace = True)
    
    return dataset_final.values

# %% [markdown]
# A função abaixo aplica a diferenciação à série, conforme o que estudamos em outras aulas e conforme o que for passado como parâmetro de ordem.

# %%
# Função para diferenciação do dataset
def difference(data, order):
    return [data[i] - data[i - order] for i in range(order, len(data))]

# %% [markdown]
# A função abaixo divide os dados de treino em treino e validação.

# %%
# Separa os dados de treino em treino e validação
def divide_treino_valid(dados, num):
    return dados[:-num], dados[-num:]

# %% [markdown]
# A próxima função será usada para treinar o modelo com as diferentes combinações de hiperparâmetros.

# %%
# Função para treinar o modelo
def treina_modelo(train, config):
    
    # Hiperparâmetros para o modelo
    n_input, n_nodes, n_epochs, n_batch, n_diff = config
    
    # Checa se devemos aplicar a diferenciação
    if n_diff > 0:
        train = difference(train, n_diff)
    
    # Transforma a série em formato de aprendizagem supervisionada
    data = transforma_serie(train, num_input = n_input)
    
    # Separa x e y
    train_x, train_y = data[:, :-1], data[:, -1]
    
    # Reshape dos dados para o formato [samples, timesteps, features]
    n_features = 1
    train_x = train_x.reshape((train_x.shape[0], train_x.shape[1], n_features))
    
    # Define o modelo
    model = Sequential()
    model.add(Bidirectional(LSTM(n_nodes, activation = 'relu', input_shape = (n_input, n_features))))
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mse')
    
    # Treinamento
    model.fit(train_x, train_y, epochs = n_epochs, batch_size = n_batch, verbose = 0)
    
    return model

# %% [markdown]
# Se temos função ara treinar o modelo precisamos de uma para fazer as previsões com o modelo treinado. É o que temos abaixo.

# %%
# Função para as previsões do modelo
def previsao_serie(model, history, config):
    
    # Extrai somente os hiperparâmetros de interesse
    # Os sinais _ absorvem o retorno da função que não é do nosso interesse neste momento
    n_input, _, _, _, n_diff = config
    
    # Prepara os dados
    correction = 0.0
    
    if n_diff > 0:
        correction = history[-n_diff]
        history = difference(history, n_diff)
    
    # Reshape dos dados no formato [samples, timesteps, features]
    x_input = np.array(history[-n_input:]).reshape((1, n_input, 1))
    
    # Previsão
    yhat = model.predict(x_input, verbose = 0)
    
    return correction + yhat[0]

# %% [markdown]
# Os modelos de previsão de séries temporais podem ser avaliados em um conjunto de testes usando a validação Walk-forward.
#
# A validação Walk-forward é uma abordagem em que o modelo faz uma previsão para cada observação no conjunto de dados de teste, uma de cada vez. Depois que cada previsão é feita para uma etapa no conjunto de dados de teste, a observação verdadeira para a previsão é adicionada ao conjunto de dados de teste e disponibilizada ao modelo.
#
# Modelos mais simples podem ser reajustados com a observação antes de fazer a previsão subsequente. Modelos mais complexos, como redes neurais, não são reajustados, dado o custo computacional muito maior.
#
# No entanto, a observação verdadeira para o intervalo de tempo pode ser usada como parte da entrada para fazer a previsão no próximo intervalo de tempo.
#
# Primeiro, o conjunto de dados é dividido em conjuntos de treino e teste.
#
# Um modelo será ajustado uma vez no conjunto de dados de treinamento para uma determinada configuração.
#
# Definiremos uma função genérica para executar esta operação que pode ser preenchida para o tipo de rede neural que nos interessa mais tarde. A função pega o conjunto de dados de treinamento e a configuração do modelo e retorna o modelo ajustado pronto para fazer previsões.

# %%
# Validação Walk-forward para dados univariados
def walk_forward_validation(data, n_test, cfg):
    
    # Lista para as previsões
    predictions = list()
    
    # Divide o dataset
    train, valid = divide_treino_valid(data, n_test)
    
    # Treinao o modelo
    model = treina_modelo(train, cfg)
    
    # Grava o histórico
    history = [x for x in train]
    
    # Um passo para frente com os dados de validação
    for i in range(len(valid)):
        
        # Faz a previsão
        yhat = previsao_serie(model, history, cfg)
        
        # Armazena a previsão
        predictions.append(yhat)
        
        # Armazena o histórico
        history.append(valid[i])
    
    # Estima o erro de previsão
    erro =  math.sqrt(mean_squared_error(valid, predictions))
    print('\n')
    print('Erro estimado para o modelo = %.4f' % erro)
    return erro

# %% [markdown]
# A função abaixo avalia o modelo.

# %%
# Avalia o modelo
def avalia_modelo(data, config, n_test, n_repeats = 10):
    
    # Gera a lista de hiperparâmetros
    key = str(config)
    
    # Treina e avalia o modelo
    scores = [walk_forward_validation(data, n_test, config) for _ in range(n_repeats)]
    
    # Sore
    result = np.mean(scores)
    print('\n')
    print('Erro do Modelo com Hiperparâmetros [%s] é igual a %.4f' % (key, result))
    return (key, result)

# %% [markdown]
# Função para o Grid Search.

# %%
# Função para o Grid Search
def grid_search(data, cfg_list, n_test):
    
    # Gera os scores
    scores = [avalia_modelo(data, cfg, n_test) for cfg in cfg_list]
    
    # Ordena os hiperparâmetros pelo erro
    scores.sort(key = lambda tup: tup[1])
    return scores

# %% [markdown]
# Aqui listamos os hiperparâmetros que queremos testar. Colocamos apenas algumas combinações pois o processo é demorado. Fique à vontade para testar outras combinações.

# %%
# Lista de hiperparâmetros que serão testados
def lista_hiperparametros():
    n_input = [24]
    n_nodes = [50, 100]
    n_epochs = [50, 100, 200]
    n_batch = [5, 10]
    n_diff = [12]
    configs = list()
    for i in n_input:
        for j in n_nodes:
            for k in n_epochs:
                for l in n_batch:
                    for m in n_diff:
                        cfg = [i, j, k, l, m]
                        configs.append(cfg)
                        
    print('\nTotal de Combinações de Hiperparâmetros: %d' % len(configs))
    return configs

# %%
# Define o dataset (estamos usando os dados já normalizados)
data = trainset

# %%
# Split
n_test = 1

# %%
# Lista de hiperparâmetros
cfg_list = lista_hiperparametros()
# Out:
# Total de Combinações de Hiperparâmetros: 12

# %%
# Grid Search
start = time()

scores = grid_search(data, cfg_list, n_test)
print('Concluído.')

print ('\nTempo gasto: %s segundos' % str(time() - start))
# Out:
# Erro estimado para o modelo = 0.0093
#
#
# Erro estimado para o modelo = 0.0327
#
#
# Erro estimado para o modelo = 0.0186
#
#
# Erro estimado para o modelo = 0.0047
#
#
# Erro estimado para o modelo = 0.0148
#
#
# Erro estimado para o modelo = 0.0205
#
#
# Erro estimado para o modelo = 0.0033
#
#
# Erro estimado para o modelo = 0.0181
#
#
# Erro estimado para o modelo = 0.0154
#
#
# Erro estimado para o modelo = 0.0184
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 50, 5, 12]] é igual a 0.0156
#
#
# Erro estimado para o modelo = 0.0061
#
#
# Erro estimado para o modelo = 0.0144
#
#
# Erro estimado para o modelo = 0.0065
#
#
# Erro estimado para o modelo = 0.0138
#
#
# Erro estimado para o modelo = 0.0130
#
#
# Erro estimado para o modelo = 0.0056
#
#
# Erro estimado para o modelo = 0.0055
#
#
# Erro estimado para o modelo = 0.0095
#
#
# Erro estimado para o modelo = 0.0000
#
#
# Erro estimado para o modelo = 0.0092
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 50, 10, 12]] é igual a 0.0084
#
#
# Erro estimado para o modelo = 0.0842
#
#
# Erro estimado para o modelo = 0.0783
#
#
# Erro estimado para o modelo = 0.0508
#
#
# Erro estimado para o modelo = 0.1302
#
#
# Erro estimado para o modelo = 0.1037
#
#
# Erro estimado para o modelo = 0.0812
#
#
# Erro estimado para o modelo = 0.0880
#
#
# Erro estimado para o modelo = 0.0775
#
#
# Erro estimado para o modelo = 0.0805
#
#
# Erro estimado para o modelo = 0.0651
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 100, 5, 12]] é igual a 0.0840
#
#
# Erro estimado para o modelo = 0.0268
#
#
# Erro estimado para o modelo = 0.0385
#
#
# Erro estimado para o modelo = 0.0696
#
#
# Erro estimado para o modelo = 0.0545
#
#
# Erro estimado para o modelo = 0.0603
#
#
# Erro estimado para o modelo = 0.0293
#
#
# Erro estimado para o modelo = 0.1168
#
#
# Erro estimado para o modelo = 0.0067
#
#
# Erro estimado para o modelo = 0.0602
#
#
# Erro estimado para o modelo = 0.0409
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 100, 10, 12]] é igual a 0.0504
#
#
# Erro estimado para o modelo = 0.1239
#
#
# Erro estimado para o modelo = 0.0831
#
#
# Erro estimado para o modelo = 0.1683
#
#
# Erro estimado para o modelo = 0.1386
#
#
# Erro estimado para o modelo = 0.1107
#
#
# Erro estimado para o modelo = 0.0044
#
#
# Erro estimado para o modelo = 0.0406
#
#
# Erro estimado para o modelo = 0.0718
#
#
# Erro estimado para o modelo = 0.0949
#
#
# Erro estimado para o modelo = 0.0134
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 200, 5, 12]] é igual a 0.0850
#
#
# Erro estimado para o modelo = 0.0663
#
#
# Erro estimado para o modelo = 0.0802
#
#
# Erro estimado para o modelo = 0.1024
#
#
# Erro estimado para o modelo = 0.1483
#
#
# Erro estimado para o modelo = 0.0655
#
#
# Erro estimado para o modelo = 0.1263
#
#
# Erro estimado para o modelo = 0.0824
#
#
# Erro estimado para o modelo = 0.0432
#
#
# Erro estimado para o modelo = 0.0957
#
#
# Erro estimado para o modelo = 0.1462
#
#
# Erro do Modelo com Hiperparâmetros [[24, 50, 200, 10, 12]] é igual a 0.0957
#
#
# Erro estimado para o modelo = 0.0279
#
#
# Erro estimado para o modelo = 0.0308
#
#
# Erro estimado para o modelo = 0.0422
#
#
# Erro estimado para o modelo = 0.0113
#
#
# Erro estimado para o modelo = 0.0363
#
#
# Erro estimado para o modelo = 0.0790
#
#
# Erro estimado para o modelo = 0.0446
#
#
# Erro estimado para o modelo = 0.0990
#
#
# Erro estimado para o modelo = 0.0358
#
#
# Erro estimado para o modelo = 0.0246
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 50, 5, 12]] é igual a 0.0431
#
#
# Erro estimado para o modelo = 0.0008
#
#
# Erro estimado para o modelo = 0.0198
#
#
# Erro estimado para o modelo = 0.0052
#
#
# Erro estimado para o modelo = 0.0146
#
#
# Erro estimado para o modelo = 0.0152
#
#
# Erro estimado para o modelo = 0.0129
#
#
# Erro estimado para o modelo = 0.0088
#
#
# Erro estimado para o modelo = 0.0087
#
#
# Erro estimado para o modelo = 0.0026
#
#
# Erro estimado para o modelo = 0.0026
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 50, 10, 12]] é igual a 0.0091
#
#
# Erro estimado para o modelo = 0.0896
#
#
# Erro estimado para o modelo = 0.0907
#
#
# Erro estimado para o modelo = 0.0702
#
#
# Erro estimado para o modelo = 0.0610
#
#
# Erro estimado para o modelo = 0.0729
#
#
# Erro estimado para o modelo = 0.1410
#
#
# Erro estimado para o modelo = 0.0974
#
#
# Erro estimado para o modelo = 0.1661
#
#
# Erro estimado para o modelo = 0.0384
#
#
# Erro estimado para o modelo = 0.0729
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 100, 5, 12]] é igual a 0.0900
#
#
# Erro estimado para o modelo = 0.0521
#
#
# Erro estimado para o modelo = 0.0967
#
#
# Erro estimado para o modelo = 0.0682
#
#
# Erro estimado para o modelo = 0.1062
#
#
# Erro estimado para o modelo = 0.0580
#
#
# Erro estimado para o modelo = 0.0728
#
#
# Erro estimado para o modelo = 0.0785
#
#
# Erro estimado para o modelo = 0.0950
#
#
# Erro estimado para o modelo = 0.1054
#
#
# Erro estimado para o modelo = 0.0888
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 100, 10, 12]] é igual a 0.0822
#
#
# Erro estimado para o modelo = 0.0865
#
#
# Erro estimado para o modelo = 0.0562
#
#
# Erro estimado para o modelo = 0.1106
#
#
# Erro estimado para o modelo = 0.1382
#
#
# Erro estimado para o modelo = 0.0784
#
#
# Erro estimado para o modelo = 0.1053
#
#
# Erro estimado para o modelo = 0.0920
#
#
# Erro estimado para o modelo = 0.1684
#
#
# Erro estimado para o modelo = 0.0729
#
#
# Erro estimado para o modelo = 0.0320
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 200, 5, 12]] é igual a 0.0941
#
#
# Erro estimado para o modelo = 0.0687
#
#
# Erro estimado para o modelo = 0.0885
#
#
# Erro estimado para o modelo = 0.0309
#
#
# Erro estimado para o modelo = 0.0234
#
#
# Erro estimado para o modelo = 0.1413
#
#
# Erro estimado para o modelo = 0.0073
#
#
# Erro estimado para o modelo = 0.0917
#
#
# Erro estimado para o modelo = 0.1335
#
#
# Erro estimado para o modelo = 0.1081
#
#
# Erro estimado para o modelo = 0.1720
#
#
# Erro do Modelo com Hiperparâmetros [[24, 100, 200, 10, 12]] é igual a 0.0865
# Concluído.
#
# Tempo gasto: 4186.467040777206 segundos

# %%
# Lista do resultado
print('\nAqui estão os hiperparâmetros que apresentaram os melhores resultados:')
for cfg, error in scores[:3]:
    print(cfg, error)
# Out:
# Aqui estão os hiperparâmetros que apresentaram os melhores resultados:
# [24, 50, 50, 10, 12] 0.008370851684637737
# [24, 100, 50, 10, 12] 0.009119381796292592
# [24, 50, 50, 5, 12] 0.01556933729460983

# %% [markdown]
# Agora que temos os melhores hiperparâmetros, vamos criar a versão final do modelo.

# %%
# Lista de hiperparâmetros com melhor performance: n_input, n_nodes, n_epochs, n_batch, n_diff 
config = [24, 50, 50, 10, 12]

# %% [markdown]
# Em relação ao nosso modelo, somente 2 hiperparâmetros devem ser modificados: número de nodes (vamos aumentar de 24 para 100) e tamanho do batch (vamos reduzir de 10 para 5). O restante se mantém igual.

# %%
# Número de repetições
n_rep = 20

# Número de epochs
num_epochs = 50

# Número de inputs (usaremos 24 séries para prever as 24 séries seguintes)
n_input = 24

# Comprimento das sequências de saída (em número de timesteps)
n_output = 24

# Aqui estamos indicando que nossa série é univariada, logo, apenas 1 recurso
n_features = 1

# Número de amostras de séries temporais em cada lote
size_batch = 10

# %%
# Criação e treinamento do modelo LSTM Padrão
start = time()

# Criamos uma matriz preenchida com zeros que receberá o resultado das previsões do nosso modelo
resultado = np.zeros((n_input, n_rep))

# Loop
# Vamos repetir o processo de treinamento por 20 vezes e armazenar todos os resultados, pois assim usaremos
# diferentes amostras. Ao final, tiramos a média para encontrar as previsões.
for i in range(n_rep):
    
    # O primeiro passo é criar o modelo, ou seja, um objeto da classe Sequential() do Keras
    modelo_lstm = Sequential()
    
    # Modelo Bidirectional
    modelo_lstm.add(Bidirectional(LSTM(100, activation = 'relu'), input_shape = (24, 1)))
    modelo_lstm.add(Dense(1))
    
    # Com as camadas prontas, podemos definir a função de perda, nesse caso usaremos o MSE (Mean Squared Error)
    # E indicamos o algoritmo de otimização (minimização da função de perda), em nosso caso ADAM
    modelo_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    # Aqui fazemos o treinamento gerando batches de dados
    modelo_lstm.fit_generator(generator, epochs = num_epochs)
    
    # Lista para as previsões
    pred_list = []

    # Gera um batch de dados
    batch = trainset[-n_input:].reshape((1, n_input, n_features))

    # Loop para fazer as previsões
    for j in range(n_input):   
        pred_list.append(modelo_lstm.predict(batch)[0]) 
        batch = np.append(batch[:,1:,:], [[pred_list[j]]], axis = 1)

    # Gera o dataframe com as previsões
    df_predict_modelo_lstm = pd.DataFrame(scaler.inverse_transform(pred_list),
                                      index = target[-n_input:].index, columns = ['Prediction'])

    resultado[:,i] = df_predict_modelo_lstm['Prediction']
    
print(resultado)

print ('\nTempo gasto: %s segundos' % str(time() - start))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1844
# Epoch 2/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.1060
# Epoch 3/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0552
# Epoch 4/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0261
# Epoch 5/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0319
# Epoch 6/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0252
# Epoch 7/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0265
# Epoch 8/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0248
# Epoch 9/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0235
# Epoch 10/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0235
# Epoch 11/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0225
# Epoch 12/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0223
# Epoch 13/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0225
# Epoch 14/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 15/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0219
# Epoch 16/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0224
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 18/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 19/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0219
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 21/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0215
# Epoch 22/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0216
# Epoch 23/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0214
# Epoch 24/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0214
# Epoch 25/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0214
# Epoch 26/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0213
# Epoch 27/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 28/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0212
# Epoch 29/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0209
# Epoch 30/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0209
# Epoch 31/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0208
# Epoch 32/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0207
# Epoch 33/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0205
# Epoch 34/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0206
# Epoch 35/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0201
# Epoch 36/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0206
# Epoch 37/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0193
# Epoch 38/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0197
# Epoch 39/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0196
# Epoch 40/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0184
# Epoch 41/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0190
# Epoch 42/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0189
# Epoch 43/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0186
# Epoch 44/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0192
# Epoch 45/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0190
# Epoch 46/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0172
# Epoch 47/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0184
# Epoch 48/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0189
# Epoch 49/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0172
# Epoch 50/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0191
# Epoch 1/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.1814
# Epoch 2/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0985
# Epoch 3/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0417
# Epoch 4/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0337
# Epoch 5/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0262
# Epoch 6/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0233
# Epoch 7/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0243
# Epoch 8/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0225
# Epoch 9/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0221
# Epoch 10/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0224
# Epoch 11/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0221
# Epoch 12/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0217
# Epoch 13/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0218
# Epoch 14/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0218
# Epoch 15/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0216
# Epoch 16/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0215
# Epoch 17/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0215
# Epoch 18/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0215
# Epoch 19/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 20/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0214
# Epoch 21/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 22/50
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0211
# Epoch 23/50
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0214
# Epoch 24/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0210
# Epoch 25/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0213
# Epoch 26/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 27/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0208
# Epoch 28/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0206
# Epoch 29/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0204
# Epoch 30/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0204
# Epoch 31/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0204
# Epoch 32/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0200
# Epoch 33/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0198
# Epoch 34/50
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0194
# Epoch 35/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0202
# Epoch 36/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0187
# Epoch 37/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0196
# Epoch 38/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0177
# Epoch 39/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0191
# Epoch 40/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0195
# Epoch 41/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0202
# Epoch 42/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0193
# Epoch 43/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0182
# Epoch 44/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0192
# Epoch 45/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0192
# Epoch 46/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0187
# Epoch 47/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0180
# Epoch 48/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0176
# Epoch 49/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0175
# Epoch 50/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0164
# Epoch 1/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1781
# Epoch 2/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0956
# Epoch 3/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0288
# Epoch 4/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0353
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0250
# Epoch 6/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0249
# Epoch 7/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0255
# Epoch 8/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0235
# Epoch 9/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0226
# Epoch 10/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0229
# Epoch 11/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0223
# Epoch 12/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0222
# Epoch 13/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0224
# Epoch 14/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0221
# Epoch 15/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0220
# Epoch 16/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0221
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 18/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 19/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 20/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 21/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0218
# Epoch 22/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 24/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0219
# Epoch 25/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0216
# Epoch 26/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 27/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0216
# Epoch 28/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 29/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0213
# Epoch 30/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 31/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 32/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 33/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0214
# Epoch 34/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 35/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0210
# Epoch 36/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0211
# Epoch 37/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0213
# Epoch 38/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0209
# Epoch 39/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0206
# Epoch 40/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0208
# Epoch 41/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0209
# Epoch 42/50
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0206
# Epoch 43/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0204
# Epoch 44/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0202
# Epoch 45/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0205
# Epoch 46/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0205
# Epoch 47/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0198
# Epoch 48/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0199
# Epoch 49/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0194
# Epoch 50/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0192
# Epoch 1/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1804
# Epoch 2/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1081
# Epoch 3/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0500
# Epoch 4/50
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0253
# Epoch 5/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0285
# Epoch 6/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0220
# Epoch 7/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0244
# Epoch 8/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0231
# Epoch 9/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0217
# Epoch 10/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0228
# Epoch 11/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0222
# Epoch 12/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0218
# Epoch 13/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0221
# Epoch 14/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0218
# Epoch 15/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0217
# Epoch 16/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0217
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 18/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0217
# Epoch 19/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0214
# Epoch 21/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 22/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0212
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212
# Epoch 24/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 25/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 26/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 27/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0211
# Epoch 28/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0209
# Epoch 29/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0208
# Epoch 30/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0207
# Epoch 31/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0211
# Epoch 32/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212
# Epoch 33/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0206
# Epoch 34/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0203
# Epoch 35/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0205
# Epoch 36/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0207
# Epoch 37/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0200
# Epoch 38/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0201
# Epoch 39/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0198
# Epoch 40/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0194
# Epoch 41/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0194
# Epoch 42/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0194
# Epoch 43/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0188
# Epoch 44/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0189
# Epoch 45/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0179
# Epoch 46/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0180
# Epoch 47/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0169
# Epoch 48/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0165
# Epoch 49/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0165
# Epoch 50/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0159
# Epoch 1/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1575
# Epoch 2/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0658
# Epoch 3/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0282
# Epoch 4/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0284
# Epoch 5/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0232
# Epoch 6/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0243
# Epoch 7/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0230
# Epoch 8/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0219
# Epoch 9/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0223
# Epoch 10/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0222
# Epoch 11/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 12/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0223
# Epoch 13/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0221
# Epoch 14/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0219
# Epoch 15/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0221
# Epoch 16/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0218
# Epoch 17/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0217
# Epoch 18/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 19/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 20/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0220
# Epoch 21/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0218
# Epoch 22/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0215
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 24/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 25/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0216
# Epoch 26/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0214
# Epoch 27/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 28/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 29/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 30/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0215
# Epoch 31/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0214
# Epoch 32/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 33/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0213
# Epoch 34/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0214
# Epoch 35/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0214
# Epoch 36/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0213
# Epoch 37/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 38/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 39/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0211
# Epoch 40/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 41/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0211
# Epoch 42/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0210
# Epoch 43/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0215
# Epoch 44/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0210
# Epoch 45/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 46/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0209
# Epoch 47/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0209
# Epoch 48/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0208
# Epoch 49/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0212
# Epoch 50/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0207
# Epoch 1/50
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1766
# Epoch 2/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1066
# Epoch 3/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0449
# Epoch 4/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0296
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0268
# Epoch 6/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0239
# Epoch 7/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0246
# Epoch 8/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0227
# Epoch 9/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 10/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0226
# Epoch 11/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0221
# Epoch 12/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0220
# Epoch 13/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0221
# Epoch 14/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0218
# Epoch 15/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0218
# Epoch 16/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0219
# Epoch 17/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0216
# Epoch 18/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 19/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 21/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0217
# Epoch 22/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0213
# Epoch 23/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0217
# Epoch 24/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0214
# Epoch 25/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0213
# Epoch 26/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0214
# Epoch 27/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0217
# Epoch 28/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0213
# Epoch 29/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0209
# Epoch 30/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0214
# Epoch 31/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0214
# Epoch 32/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0210
# Epoch 33/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0209
# Epoch 34/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0209
# Epoch 35/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0207
# Epoch 36/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0205
# Epoch 37/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0206
# Epoch 38/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0204
# Epoch 39/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0203
# Epoch 40/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0203
# Epoch 41/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0198
# Epoch 42/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0202
# Epoch 43/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0196
# Epoch 44/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0197
# Epoch 45/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0196
# Epoch 46/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0203
# Epoch 47/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0196
# Epoch 48/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0189
# Epoch 49/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0198
# Epoch 50/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0177
# Epoch 1/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1658
# Epoch 2/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0865
# Epoch 3/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0326
# Epoch 4/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0429
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0246
# Epoch 6/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0243
# Epoch 7/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0262
# Epoch 8/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0238
# Epoch 9/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0224
# Epoch 10/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0223
# Epoch 11/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0226
# Epoch 12/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0226
# Epoch 13/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0221
# Epoch 14/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0221
# Epoch 15/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0220
# Epoch 16/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0220
# Epoch 17/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0220
# Epoch 18/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0218
# Epoch 19/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0219
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 21/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0220
# Epoch 22/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0218
# Epoch 23/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0217
# Epoch 24/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0216
# Epoch 25/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 26/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0215
# Epoch 27/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0217
# Epoch 28/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0215
# Epoch 29/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0214
# Epoch 30/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 31/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0214
# Epoch 32/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 33/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 34/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 35/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0211
# Epoch 36/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 37/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 38/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0210
# Epoch 39/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0211
# Epoch 40/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0209
# Epoch 41/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0207
# Epoch 42/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0208
# Epoch 43/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0207
# Epoch 44/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0205
# Epoch 45/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0205
# Epoch 46/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0206
# Epoch 47/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0205
# Epoch 48/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0201
# Epoch 49/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0201
# Epoch 50/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0201
# Epoch 1/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1552
# Epoch 2/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0799
# Epoch 3/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0294
# Epoch 4/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0291
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0235
# Epoch 6/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0229
# Epoch 7/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0230
# Epoch 8/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0221
# Epoch 9/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0220
# Epoch 10/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0225
# Epoch 11/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0223
# Epoch 12/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0219
# Epoch 13/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0218
# Epoch 14/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0216
# Epoch 15/50
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0218
# Epoch 16/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0219
# Epoch 17/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0215
# Epoch 18/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0214
# Epoch 19/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0215
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 21/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0215
# Epoch 22/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0213
# Epoch 23/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 24/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0214
# Epoch 25/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 26/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0210
# Epoch 27/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0210
# Epoch 28/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0209
# Epoch 29/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0207
# Epoch 30/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0210
# Epoch 31/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0208
# Epoch 32/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0208
# Epoch 33/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0205
# Epoch 34/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0204
# Epoch 35/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 36/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0202
# Epoch 37/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0201
# Epoch 38/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0200
# Epoch 39/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0198
# Epoch 40/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0199
# Epoch 41/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0202
# Epoch 42/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0203
# Epoch 43/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0194
# Epoch 44/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0193
# Epoch 45/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0189
# Epoch 46/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0187
# Epoch 47/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0184
# Epoch 48/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0180
# Epoch 49/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0185
# Epoch 50/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0182
# Epoch 1/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.2107
# Epoch 2/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1393
# Epoch 3/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0800
# Epoch 4/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0356
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0333
# Epoch 6/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0232
# Epoch 7/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0232
# Epoch 8/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0242
# Epoch 9/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0226
# Epoch 10/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0221
# Epoch 11/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0223
# Epoch 12/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0220
# Epoch 13/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0221
# Epoch 14/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 15/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0217
# Epoch 16/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 17/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 18/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 19/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0217
# Epoch 20/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0216
# Epoch 21/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 22/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212
# Epoch 24/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0215
# Epoch 25/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 26/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 27/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0210
# Epoch 28/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0211
# Epoch 29/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0208
# Epoch 30/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0206
# Epoch 31/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0205
# Epoch 32/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0206
# Epoch 33/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0210
# Epoch 34/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0201
# Epoch 35/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0205
# Epoch 36/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0204
# Epoch 37/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0201
# Epoch 38/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0199
# Epoch 39/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0193
# Epoch 40/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0190
# Epoch 41/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0185
# Epoch 42/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0177
# Epoch 43/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0202
# Epoch 44/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0185
# Epoch 45/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0171
# Epoch 46/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0180
# Epoch 47/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0183
# Epoch 48/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0184
# Epoch 49/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0167
# Epoch 50/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0163
# Epoch 1/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.1672
# Epoch 2/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0991
# Epoch 3/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0401
# Epoch 4/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0325
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0286
# Epoch 6/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0256
# Epoch 7/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0262
# Epoch 8/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0232
# Epoch 9/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0222
# Epoch 10/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0227
# Epoch 11/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0222
# Epoch 12/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0217
# Epoch 13/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0219
# Epoch 14/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0220
# Epoch 15/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0218
# Epoch 16/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0217
# Epoch 17/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0217
# Epoch 18/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0217
# Epoch 19/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0216
# Epoch 20/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0214
# Epoch 21/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0214
# Epoch 22/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0213
# Epoch 23/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0213
# Epoch 24/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 25/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0212
# Epoch 26/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0211
# Epoch 27/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 28/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0212
# Epoch 29/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0209
# Epoch 30/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 31/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0208
# Epoch 32/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0211
# Epoch 33/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0208
# Epoch 34/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0206
# Epoch 35/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 36/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0203
# Epoch 37/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0203
# Epoch 38/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0200
# Epoch 39/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0199
# Epoch 40/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0199
# Epoch 41/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0197
# Epoch 42/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0196
# Epoch 43/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0194
# Epoch 44/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0189
# Epoch 45/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0187
# Epoch 46/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0184
# Epoch 47/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0192
# Epoch 48/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0181
# Epoch 49/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0183
# Epoch 50/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0177
# Epoch 1/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2146
# Epoch 2/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.1289
# Epoch 3/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0720
# Epoch 4/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0297
# Epoch 5/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0375
# Epoch 6/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0232
# Epoch 7/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0244
# Epoch 8/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0255
# Epoch 9/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0231
# Epoch 10/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 11/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0224
# Epoch 12/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 13/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 14/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 15/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 16/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 17/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 18/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0215
# Epoch 19/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0214
# Epoch 21/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212
# Epoch 22/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0211
# Epoch 24/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 25/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0210
# Epoch 26/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0209
# Epoch 27/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0210
# Epoch 28/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0207
# Epoch 29/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0206
# Epoch 30/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0207
# Epoch 31/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 32/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0211
# Epoch 33/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0209
# Epoch 34/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0205
# Epoch 35/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0205
# Epoch 36/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0200
# Epoch 37/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0198
# Epoch 38/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0196
# Epoch 39/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0199
# Epoch 40/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0189
# Epoch 41/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0196
# Epoch 42/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0186
# Epoch 43/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0174
# Epoch 44/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0167
# Epoch 45/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0294
# Epoch 46/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0240
# Epoch 47/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0203
# Epoch 48/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0209
# Epoch 49/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0191
# Epoch 50/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0191
# Epoch 1/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1994
# Epoch 2/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.1151
# Epoch 3/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0566
# Epoch 4/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0232
# Epoch 5/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0333
# Epoch 6/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0233
# Epoch 7/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0240
# Epoch 8/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0249
# Epoch 9/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0228
# Epoch 10/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 11/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0226
# Epoch 12/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0224
# Epoch 13/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0223
# Epoch 14/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0222
# Epoch 15/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0218
# Epoch 16/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0218
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 18/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 19/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 20/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0217
# Epoch 21/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 22/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0216
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 24/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0216
# Epoch 25/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 26/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 27/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0214
# Epoch 28/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0215
# Epoch 29/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 30/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 31/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 32/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 33/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0216
# Epoch 34/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 35/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 36/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0212
# Epoch 37/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212
# Epoch 38/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0209
# Epoch 39/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0209
# Epoch 40/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0209
# Epoch 41/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0207
# Epoch 42/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0206
# Epoch 43/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0205
# Epoch 44/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0204
# Epoch 45/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0203
# Epoch 46/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0202
# Epoch 47/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0202
# Epoch 48/50
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0200
# Epoch 49/50
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0199
# Epoch 50/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0195
# Epoch 1/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1554
# Epoch 2/50
# ...
# Epoch 7/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0244
# Epoch 8/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0223
# Epoch 9/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0226
# Epoch 10/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0224
# Epoch 11/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0220
# Epoch 12/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0219
# Epoch 13/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 14/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0217
# Epoch 15/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0215
# Epoch 16/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0216
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 18/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0213
# Epoch 19/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0213
# Epoch 20/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 21/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0212
# Epoch 22/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0213
# Epoch 23/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0213
# Epoch 24/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0210
# Epoch 25/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0206
# Epoch 26/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0212
# Epoch 27/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0212
# Epoch 28/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0207
# Epoch 29/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0204
# Epoch 30/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 31/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0209
# Epoch 32/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0200
# Epoch 33/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0198
# Epoch 34/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0196
# Epoch 35/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0195
# Epoch 36/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0191
# Epoch 37/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0192
# Epoch 38/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0192
# Epoch 39/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0181
# Epoch 40/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0171
# Epoch 41/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0164
# Epoch 42/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0162
# Epoch 43/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0202
# Epoch 44/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0209
# Epoch 45/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0207
# Epoch 46/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0199
# Epoch 47/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0190
# Epoch 48/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0193
# Epoch 49/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0190
# Epoch 50/50
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0180
# Epoch 1/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1619
# Epoch 2/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0917
# Epoch 3/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0344
# Epoch 4/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0291
# Epoch 5/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0237
# Epoch 6/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0224
# Epoch 7/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0234
# Epoch 8/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0220
# Epoch 9/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0221
# Epoch 10/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0223
# Epoch 11/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0220
# Epoch 12/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0217
# Epoch 13/50
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0215
# Epoch 14/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0215
# Epoch 15/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0214
# Epoch 16/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0214
# Epoch 17/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0216
# Epoch 18/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0214
# Epoch 19/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0213
# Epoch 20/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0216
# Epoch 21/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0212
# Epoch 22/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0212
# Epoch 23/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0210
# Epoch 24/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0209
# Epoch 25/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0208
# Epoch 26/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0207
# Epoch 27/50
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0209
# Epoch 28/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0208
# Epoch 29/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0205
# Epoch 30/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0207
# Epoch 31/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0202
# Epoch 32/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0204
# Epoch 33/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0200
# Epoch 34/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0204
# Epoch 35/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0198
# Epoch 36/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0199
# Epoch 37/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0208
# Epoch 38/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0190
# Epoch 39/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0192
# Epoch 40/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0186
# Epoch 41/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0185
# Epoch 42/50
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0177
# Epoch 43/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0173
# Epoch 44/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0174
# Epoch 45/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0176
# Epoch 46/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0195
# Epoch 47/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0160
# Epoch 48/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0190
# Epoch 49/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0155
# Epoch 50/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0165
# [[4460392.16331697 4638077.32533765 4433108.40056419 4769888.07322431
#   4256370.76245308 4331602.39878273 4338118.32767987 4638008.44363332
#   4719116.65048242 4464226.71168303 4429899.99489999 4355473.51360846
#   4290592.1543045  4424819.76896811 4345684.70256805 4377569.52288508
#   5032955.11132526 4594567.71622729 4437163.81090665 4679671.86287761]
#  [4152569.63830233 4261923.14843965 4214735.57669806 4286143.27724981
#   4127093.6198132  4046078.12293243 4160901.52120113 4275839.05485201
#   4224492.14949894 4097216.18055987 4244132.04544616 4142952.2305727
#   4111024.55942798 4148578.10372639 4180171.77870011 4072433.08398306
#   4555354.40318704 4257049.56762075 4207511.00724387 4210992.73711276]
#  [4148983.18421435 4265136.76027918 4208717.63849473 4284336.53417373
#   4124180.76471758 4030199.08794665 4157275.42008567 4272563.16914606
#   4225026.38318253 4086372.81865942 4242846.12014031 4139537.38003302
#   4102699.08412957 4143703.52171993 4175444.37126541 4061243.31118584
#   4579867.47947812 4258904.16746235 4202475.03380227 4204724.10154366]
#  [4090170.72356069 4196995.7345078  4171515.91150594 4192250.70617199
#   4110888.39791942 3972285.99408078 4129453.21866155 4203769.96979618
#   4133643.58908749 4012707.44015324 4208359.61382222 4105957.94964695
#   4068853.43797052 4094136.22725999 4142209.54963851 4000813.532143
#   4497457.52855968 4198788.66119552 4156767.81799126 4110513.15282083]
#  [4054214.97449398 4154032.97404432 4156275.83442283 4131060.32493758
#   4116010.47349143 3939192.13966274 4119615.34943056 4161708.87885189
#   4076049.1732229  3966191.46502888 4193403.47353196 4093510.58515191
#   4053498.6247927  4068639.18383205 4125524.15818954 3964935.1748749
#   4443522.75359392 4164070.88055038 4134246.7044754  4050427.48194337]
#  [4065079.56157076 4166003.7732594  4173891.32911777 4144189.6984005
#   4140431.84100175 3949712.0178616  4135519.61434293 4172350.70169592
#   4090021.84697008 3971653.54389727 4208543.8323338  4111597.03847647
#   4066061.5263325  4082311.30107284 4135698.82691669 3973785.67293131
#   4466564.28440499 4180483.74874473 4148195.65007734 4057864.50339842]
#  [4071246.57660222 4168644.70581293 4189374.69477868 4148065.89616919
#   4164769.70946932 3958624.18907189 4150090.49765897 4175673.84345484
#   4092266.10901117 3970022.40911973 4219896.49834752 4127345.91907907
#   4076111.04661429 4091731.07437754 4143664.47540498 3978152.65284336
#   4479217.09258795 4189273.77507234 4157584.18633008 4054171.32271624]
#  [4072250.26713407 4161648.80759811 4204448.17425132 4139651.91589022
#   4190807.99489379 3965680.15854049 4164889.85197687 4172302.84493041
#   4082443.45783114 3962264.60716951 4229296.8486135  4142583.39307451
#   4085207.93692994 4098459.65551305 4150525.81401134 3978269.19107568
#   4475925.58835602 4191051.28347158 4164566.46839404 4039924.22345805]
#  [4083534.75227475 4165180.99732018 4231505.06790233 4142724.56052089
#   4224169.56686616 3984352.10635185 4189023.87865663 4182213.40037847
#   4086032.31476927 3967851.23377073 4248400.10802698 4167929.85789299
#   4103855.8562398  4117735.51966238 4166085.06968951 3989663.40637326
#   4481829.7916522  4204586.73861003 4183246.82618093 4041532.73139668]
#  [4119998.20355463 4200224.56439829 4279985.17278767 4183048.39080596
#   4267380.02113271 4026920.59915304 4229551.95120454 4225515.76366329
#   4129125.02937841 4006652.65824759 4287747.9806757  4211740.22374725
#   4140775.24833584 4162897.48872662 4199223.37683535 4027730.25953519
#   4525344.8071754  4247838.44180417 4226123.28427649 4085843.4907949 ]
#  [4194922.67553997 4287824.07093048 4354811.12791681 4286416.00074196
#   4318887.51697087 4102886.30620384 4290110.78332424 4321647.99131942
#   4238083.87137842 4097132.2810421  4354391.83056545 4278494.20426893
#   4201506.48495388 4244223.95446444 4255919.62733722 4106171.40283537
#   4639802.77198362 4337131.35698032 4301713.74622869 4197464.09004974]
#  [4293276.93887329 4414878.1767056  4442876.98761582 4434995.83935785
#   4368970.12266946 4192233.08527088 4359749.98616481 4455366.00151348
#   4392664.62800908 4227447.45494723 4438955.33593178 4355212.40389204
#   4275637.21543932 4349329.6260097  4326373.19614148 4213672.31550622
#   4822865.51264238 4457301.89778519 4398694.58046317 4364021.25254583]
#  [4605376.93763185 4814328.38629317 4624235.50680494 4974803.5345819
#   4434727.32085347 4448941.38092208 4503781.22944474 4832004.35271692
#   4893062.37695551 4585576.45119953 4608850.45776272 4525198.83402872
#   4422030.86089277 4584420.68027687 4475957.22588301 4499686.77278733
#   5485484.68122482 4791925.81338477 4597684.01263571 4833740.61218858]
#  [4297814.72138357 4433273.59651208 4399538.18110371 4471377.79397011
#   4302143.65616822 4180718.42710948 4322750.09858871 4457262.45099521
#   4404037.31777406 4223438.69994521 4425021.60838079 4308829.38647604
#   4242911.19733191 4311582.25179911 4317166.27531266 4199952.84209371
#   4968353.68406391 4452457.55164313 4376705.69825578 4367438.70617318]
#  [4321822.5984304  4469150.35188007 4406362.47577024 4512492.5624299
#   4299509.73192763 4191577.70789218 4330349.31242895 4483984.94800019
#   4449393.31698799 4248248.52822995 4437273.94153857 4319638.20740557
#   4248196.66671419 4326947.07685256 4325487.94609833 4216107.80437183
#   5069129.82011199 4481350.02257204 4390401.74387932 4402923.19625401]
#  [4246746.34641051 4379656.39824128 4355419.84995508 4384370.38976264
#   4272202.34114838 4122170.38009119 4291543.68296432 4393771.9414537
#   4332916.95805287 4162518.6393528  4392694.86387348 4273447.81847668
#   4206382.26838541 4264795.1550827  4284782.86358929 4143962.2285862
#   4964222.5839417  4401700.54600215 4337330.99378037 4287951.02151346]
#  [4255691.55681038 4394471.17084765 4363456.18228531 4396505.38373804
#   4277887.08413076 4125989.7104063  4299083.22602582 4403863.11113811
#   4350976.57955074 4173406.95457482 4403636.64251137 4282510.56829643
#   4212885.58231926 4275829.84392643 4291416.33190632 4151416.0699923
#   5006248.23284626 4416558.16943622 4347784.19288754 4301468.25503826]
#  [4263829.81003451 4406865.87287688 4369480.12761402 4409829.5883007
#   4281501.5714705  4129506.68207741 4304111.59044194 4411391.04042387
#   4365863.23742414 4181546.60946155 4411644.74135232 4288567.75305223
#   4217024.69194198 4282251.66119266 4296486.34572506 4157480.46329856
#   5055338.46143246 4429315.10112572 4354469.52272034 4311574.64277363]
#  [4248089.73988247 4386787.05630207 4360555.54167795 4380387.46539974
#   4278684.22966838 4113737.77772355 4297579.04183125 4388903.36657262
#   4339305.3356545  4161014.85563326 4404155.05743146 4280243.87965393
#   4208193.61692429 4268724.0153172  4288513.28844881 4141044.16731524
#   5061756.87466097 4412893.22224331 4342950.65957117 4282330.75501013]
#  [4225074.44018555 4356333.53372502 4352465.34545684 4334099.76103973
#   4279638.36141586 4093763.08465528 4291256.9428463  4359488.07549834
#   4299560.79249334 4134596.11893487 4396822.96043301 4271758.21434546
#   4199933.41905499 4254145.12250066 4280047.24641657 4120473.56740952
#   5043518.04058933 4389325.66748667 4330903.36962628 4244292.83616877]
#  [4268948.68180633 4409338.60591984 4385412.42577815 4405163.85401988
#   4299063.20227456 4129770.99559402 4317047.73470521 4408811.98126173
#   4367834.17526054 4181479.32965732 4428724.40046358 4301779.0236578
#   4224269.68562245 4291761.140903   4305664.03187704 4159384.12133074
#   5161619.72741413 4440262.48641396 4364777.95010591 4306084.53065348]
#  [4241122.07515693 4372879.76010275 4375584.16794777 4352424.09652925
#   4297281.08841252 4105965.35843492 4307668.40937805 4375681.48337889
#   4320593.34034061 4148530.44719839 4418587.5766263  4288723.53783703
#   4211881.39119363 4271857.5321517  4294660.9805603  4132733.10911775
#   5133391.04383945 4411186.99839854 4348769.16121197 4261639.81235933]
#  [4256933.83033848 4396646.95165944 4399541.38490391 4377239.93193936
#   4313522.95377111 4117896.31038499 4324090.08802295 4403253.38791227
#   4351126.35721016 4169671.724015   4442745.43157005 4305761.74778318
#   4226506.13840055 4294161.38796639 4311229.43330193 4148817.98826647
#   5207619.49023104 4437496.80589008 4372045.77086282 4295467.93773603]
#  [4348885.69944429 4524715.26043582 4464012.85801959 4554769.50941277
#   4342095.24491739 4186397.96391654 4370827.1253612  4527820.74401855
#   4515739.21345901 4273097.40282965 4508497.02310371 4359904.36928701
#   4271697.14190412 4370485.1196897  4362729.1198771  4228433.82493424
#   5512398.00457931 4552785.35590053 4443378.38234735 4454539.220824  ]]
#
# Tempo gasto: 911.6516816616058 segundos

# %% [markdown]
# Vamos calcular o erro do modelo.

# %%
# Vamos criar uma matriz com as mesmas dimensões da matriz de resultado usada no treinamento
resultado_final = np.zeros((resultado.shape[0],1))

# %%
# Loop para gerar as previsões finais
for i in range(resultado.shape[0]):
    resultado_final[i] = np.mean(resultado[i,:])

# %%
# Previsões finais
resultado_final
# Out:
# array([[4500865.37078643],
#        [4198859.59032841],
#        [4195711.81658302],
#        [4139876.95782468],
#        [4108306.53042616],
#        [4121998.01564035],
#        [4130296.33372611],
#        [4133609.92415568],
#        [4148072.6892268 ],
#        [4189183.34781165],
#        [4270477.10475179],
#        [4379226.12787423],
#        [4677090.87142347],
#        [4373138.70725403],
#        [4396517.3979888 ],
#        [4324929.36353321],
#        [4336554.24243342],
#        [4346403.97573702],
#        [4332292.49734612],
#        [4312874.84501412],
#        [4357859.90423598],
#        [4333558.0685088 ],
#        [4357588.75260831],
#        [4458660.42921309]])

# %%
# Ajustamos o shape
resultado_final = resultado_final.reshape((24,))

# %%
# Previsões finais
resultado_final
# Out:
# array([4500865.37078643, 4198859.59032841, 4195711.81658302,
#        4139876.95782468, 4108306.53042616, 4121998.01564035,
#        4130296.33372611, 4133609.92415568, 4148072.6892268 ,
#        4189183.34781165, 4270477.10475179, 4379226.12787423,
#        4677090.87142347, 4373138.70725403, 4396517.3979888 ,
#        4324929.36353321, 4336554.24243342, 4346403.97573702,
#        4332292.49734612, 4312874.84501412, 4357859.90423598,
#        4333558.0685088 , 4357588.75260831, 4458660.42921309])

# %%
# Calculamos e imprimos a performance do modelo
modelo_lstm_performance = performance(testset, resultado_final)
#modelo_lstm_performance
# Out:
# MSE das previsões é 723916275017.6766
# RMSE das previsões é 850832.6951
# MAPE das previsões é 10.7944

# %% [markdown]
# E aí está. Quase o mesmo resultado da primeira versão, mas um modelo bem estável.
#
# Abaixo o plot das previsões.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(target.index, target.values, label = 'Valores Observados', color = 'Blue')
plt.plot(teste, label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(teste.index, resultado_final, label = 'Previsões', color = 'Red')

plt.title('Previsões Com Modelo LSTM Bidirecional')
plt.xlabel('Data')
plt.ylabel('Arrecadação')
plt.legend(loc = 'upper left')
plt.show()

# %%
# Plot
plt.figure(figsize = (20, 6))
plt.plot(teste, label = 'Dados de Teste', color = 'green')
plt.plot(target[72:].index,  resultado_final, label = 'Previsões', color = 'Red')
plt.title('Previsões Com Modelo LSTM Bidirecional')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# Vamos fazer o Forecasting para 24 meses de horizonte de previsão. A função DateOffset() vai nos ajudar a criar as datas.

# %% [markdown]
# Vejamos qual é a última data da nossa série original:

# %%
# Última data da série
target.index[-1]
# Out:
# Timestamp('2017-12-01 00:00:00')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [target.index[-1] + DateOffset(months = x) 
                                 for x in range(0, 25)]

# %%
# Visualiza as datas criadas
#datas_para_prever_forecasting

# %%
# Nossa série original é um objeto do tipo pd.Series
#type(target)

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pd.DataFrame(target)

# %%
# Visualiza os dados
#df_original.head()

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
#data_futuras

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index = data_futuras[-n_input:].index, columns = ['Prediction'])

# %%
# Concatenamos a série original com os valores de forecasting de 24 meses além da série
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
#df_forecasting

# %% [markdown]
# ### Previsão x Forecasting

# %% [markdown]
# Esse dataframe acima é para não restar qualquer dúvida do que estamos fazendo.
#
# Nas **previsões** do modelo, usamos os dados de teste, 24 meses que correspondem aos 24 últimos registros da série original (2016-01-01 a 2017-12-01. Fazemos isso para poder calcular a precisão do modelo, comparando as previsões com os valores reais. Esse é o padrão em Machine Learning.
#
# No **forecasting**, criamos 24 meses após a última data da série original. Obviamente, não temos dados históricos para esses meses e o que queremos é exatamente a previsão de vendas. O forecasting significa usar o modelo treinado e prever valores sobre novas datas.
#
# Bingo!

# %% [markdown]
# Vamos colocar o forecasting em um Plot.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(target.index, target.values, label = 'Valores Observados', color = 'Blue')
plt.plot(teste, label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(df_forecasting.index, df_forecasting['Prediction'], label = 'Forecasting',  color = 'Red')

plt.title('Forecasting Com Modelo LSTM Bidirecional')
plt.xlabel('Data')
plt.ylabel('Arrecadação')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# E aí está nosso modelo de Deep Learning para previsão de séries temporais! Conseguimos colocar essa versão do modelo entre o Top5 dos modelos que criamos até aqui. Mas dada a natureza da série que estamos usando, o Prophet foi imbatível.
#
# Se treinarmos o modelo acima por um período maior, talvez tenhamos um resultado ainda mais interessante. Você pode tentar isso se desejar.

# %% [markdown]
# Resumindo o que fizemos nesta aula:
#
# - Removemos os picos de vendas da série original.
# - Criamos a primeira versão do modelo LSTM Bidirectional (que teve boa performance).
# - Executamos o Grid Search para buscar os melhores hiperparâmetros.
# - Criamos a versão final do modelo com os melhores hiperparâmetros.

# %% [markdown]
# Como estamos até agora:
#
# - Modelo 15 --> Modelo ARMA (12,9) - AIC = 2044.48 e RMSE = 706415.3914
# - Modelo 16 --> Modelo ARIMA (2,1,1) - AIC = 2106,43 e RMSE = 1099391.3958
# - Modelo 17 --> Modelo SARIMA(0, 1, 0)x(0, 1, 1, 12) - AIC = 1251.06 e RMSE = 332666.2626
# - Modelo 18 --> Modelo SARIMA(0, 1, 1)x(0, 1, 1, 12) - AIC = 1233.47 e RMSE = 336782.4202
# - Modelo 22 --> Modelo LSTM Padrão - MAPE = 15.8048 e RMSE = 1037107.0089   -   (5 repetições)
# - Modelo 22 --> Modelo LSTM Padrão - MAPE = 11.7861 e RMSE = 878868.4191   -   (20 repetições)
# - Modelo 23 --> Modelo Stacked LSTM - MAPE = 13.1198 e RMSE = 945778.1667
# - Modelo 24 --> Modelo Stacked LSTM Profundo - MAPE = 12.3914 e RMSE = 877490.6632
# - Modelo 25 --> Modelo Bidirectional LSTM - MAPE = 10.7944 e RMSE = 850832.6951

# %% [markdown]
# Todas as aulas deste curso podem ser encontradas na timeline da Comunidade no portal da DSA: www.datascienceacademy.com.br

# %% [markdown]
# # Fim
